# %% [markdown]
# ### AntiSplodge minimal example
# In this short and minimal tutorial we are going to use the "global" dataset located at https://www.heartcellatlas.org/.
# We are going to deconvolute major heart-based cell types to check the JSD of the method.
#
# You can download the dataset direcly from https://cellgeni.cog.sanger.ac.uk/heartcellatlas/data/global_raw.h5ad.
#
# First:
# Import the packages we need for this, remember to install them with "pip install PACKAGE" in your terminal.

# %%
import anndata as ann
import scanpy as sc
import numpy as np

import antisplodge as AS

from collections import Counter

# %% [markdown]
# After importing the required packages, load the dataset into memory, remember to have the dataset in the same folder as the notebook.

# %%
SC = ann.read("global_raw.h5ad")

# %%
SC.obs
# Out:
#                                     NRP age_group     cell_source  \
# AAACCCAAGAACGCGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAAGCAAACAT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAAGCTACTGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAGTACCGCGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCATCAAACCCA-1-H0015_apex        No     50-55  Harvard-Nuclei
# ...                                 ...       ...             ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCCTACCAC-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGACGCTG-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
#
#                                                     cell_type donor  gender  \
# AAACCCAAGAACGCGT-1-H0015_apex             Smooth_muscle_cells    H5  Female
# AAACCCAAGCAAACAT-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# AAACCCAAGCTACTGT-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# AAACCCAGTACCGCGT-1-H0015_apex                       Pericytes    H5  Female
# AAACCCATCAAACCCA-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# ...                                                       ...   ...     ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCCTACCAC-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGACGCTG-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862                Endothelial   D11  Female
#
#                                     n_counts  n_genes  percent_mito  \
# AAACCCAAGAACGCGT-1-H0015_apex          688.0      480      0.004360
# AAACCCAAGCAAACAT-1-H0015_apex         3216.0     1365      0.000933
# AAACCCAAGCTACTGT-1-H0015_apex         3182.0     1521      0.000943
# AAACCCAGTACCGCGT-1-H0015_apex         1202.0      726      0.000832
# AAACCCATCAAACCCA-1-H0015_apex         3804.0     1584      0.000263
# ...                                      ...      ...           ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862    1619.0      904      0.087708
# TTTGTTGTCCTACCAC-1-HCAHeart8102862    1186.0      692      0.126476
# TTTGTTGTCGACGCTG-1-HCAHeart8102862    1672.0      847      0.145335
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862    4676.0     1925      0.163388
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862    3144.0     1422      0.097010
#
#                                     percent_ribo region           sample  \
# AAACCCAAGAACGCGT-1-H0015_apex           0.002907     AX       H0015_apex
# AAACCCAAGCAAACAT-1-H0015_apex           0.001244     AX       H0015_apex
# AAACCCAAGCTACTGT-1-H0015_apex           0.002200     AX       H0015_apex
# AAACCCAGTACCGCGT-1-H0015_apex           0.000000     AX       H0015_apex
# AAACCCATCAAACCCA-1-H0015_apex           0.001314     AX       H0015_apex
# ...                                          ...    ...              ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862      0.024707     AX  HCAHeart8102862
# TTTGTTGTCCTACCAC-1-HCAHeart8102862      0.015177     AX  HCAHeart8102862
# TTTGTTGTCGACGCTG-1-HCAHeart8102862      0.044258     AX  HCAHeart8102862
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862      0.044482     AX  HCAHeart8102862
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862      0.026081     AX  HCAHeart8102862
#
#                                     scrublet_score  source type version  \
# AAACCCAAGAACGCGT-1-H0015_apex             0.035917  Nuclei  DBD      V3
# AAACCCAAGCAAACAT-1-H0015_apex             0.147122  Nuclei  DBD      V3
# AAACCCAAGCTACTGT-1-H0015_apex             0.185751  Nuclei  DBD      V3
# AAACCCAGTACCGCGT-1-H0015_apex             0.035917  Nuclei  DBD      V3
# AAACCCATCAAACCCA-1-H0015_apex             0.108062  Nuclei  DBD      V3
# ...                                            ...     ...  ...     ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862        0.108062   CD45+  DCD      V3
# TTTGTTGTCCTACCAC-1-HCAHeart8102862        0.085546   CD45+  DCD      V3
# TTTGTTGTCGACGCTG-1-HCAHeart8102862        0.113475   CD45+  DCD      V3
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862        0.042770   CD45+  DCD      V3
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862        0.147122   CD45+  DCD      V3
#
#                                    cell_states Used
# AAACCCAAGAACGCGT-1-H0015_apex       SMC1_basic  Yes
# AAACCCAAGCAAACAT-1-H0015_apex             vCM1  Yes
# AAACCCAAGCTACTGT-1-H0015_apex             vCM1  Yes
# AAACCCAGTACCGCGT-1-H0015_apex        PC2_atria  Yes
# AAACCCATCAAACCCA-1-H0015_apex             vCM2  Yes
# ...                                        ...  ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCCTACCAC-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCGACGCTG-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862     EC5_art  Yes
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862  EC4_immune  Yes
#
# [486134 rows x 18 columns]

# %% [markdown]
# After we have loaded the dataset into memory, we remove all cells that stems from other than Nuclei sequencing ('source'), only use a specific technology to remove technology-based batch effects ('cell_source'), and, remove cell types that are defined as 'doublets' or 'NotAssigned'.

# %%
SC = SC[SC.obs['source'] == 'Nuclei']
SC = SC[SC.obs['cell_source'] == 'Harvard-Nuclei']
SC = SC[~SC.obs['cell_type'].isin(['doublets', 'NotAssigned'])]

# %% [markdown]
# Let us look at the number of cells remaining (N=163959)

# %%
SC
# Out:
# View of AnnData object with n_obs × n_vars = 163959 × 33538
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45'
#     uns: 'cell_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ### Find marker genes
# Because of the high number of genes (N=33538), we want to reduce the set of genes to a smaller one in order to speed up training and reduce memory footprint. But it would work with all the genes, but the time to get an as good model will be a lot higher.
#
# However, before we look for marker genes, we scale all profiles to 1 using scanpy's function normalize_total, as shown below:

# %%
sc.pp.normalize_total(SC, target_sum=1)
# Out:
# /home/Jesper.Lund/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_normalization.py:138: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
#
# Find the top 'key' marker genes that was found for each cell type during the univariate t-test analysis 
#
# usually you should use method='logreg', but t-test is faster for demonstration purpose
sc.tl.rank_genes_groups(SC, groupby='cell_type', method='t-test', key_added='ranks')

# %%
#
# Get the corresponding gene sets
#
def getGenes(adata, key, ct, min_genes, score_threshold=0.01):
    genes = []
    
    # get the N most correlated genes for each cell type
    for i, cell_ in enumerate(ct):
        
        # find the number of genes to include
        index = min_genes 
        while adata.uns[key]['scores'][cell_][index] > score_threshold: # hardcoded 0.01 inclusion 
            index += 1
        
        genes_ = adata.uns[key]['names'][cell_][0:index]
        scores = adata.uns[key]['scores'][cell_][0:index]
        
        print(cell_, len(genes_))
        
        genes.extend(genes_)
        
    np_genes = np.unique(np.array(genes))
    print("Length of unique genes:",len(np_genes))
    
    return np_genes

# use the top 50 for cell_type and allow some threshold to select the rest, 
# only ventricular cardiomyocytes have genes with scores above this threshold
use_genes = getGenes(SC, 'ranks', np.unique(SC.obs['cell_type']), 50, 120)
# Out:
# Adipocytes 50
# Atrial_Cardiomyocyte 50
# Endothelial 50
# Fibroblast 50
# Lymphoid 50
# Myeloid 50
# Neuronal 50
# Pericytes 50
# Smooth_muscle_cells 50
# Ventricular_Cardiomyocyte 229
# Length of unique genes: 609

# %%
SC = SC[:,use_genes] # filter SC

# %% [markdown]
# We need to scale again after removing unwanted genes, in order to again, have profiles of equal counts!

# %%
sc.pp.normalize_total(SC, target_sum=1)
# Out:
# /home/Jesper.Lund/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_normalization.py:138: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
SC # the profiles are now much smaller which will reduce memory and speed up traininig time
# Out:
# AnnData object with n_obs × n_vars = 163959 × 609
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45'
#     uns: 'cell_type_colors', 'ranks'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ### AntiSplodge experiment
# We then setup the AntiSplodge experiment, in this step we do:
#
# 1) Create a new experiment by passing SC to the AntiSplodge 'DeconvolutionExperiment' function.
# 2) We set the cell type column to 'cell_type' in the dataset
# 3) We split the dataset into 80% train, 10% validation, and, 10% test.

# %%
# SC should be the single-cell dataset formatted as .h5ad (AnnData)
Exp = AS.DeconvolutionExperiment(SC) 
Exp.setVerbosity(True)

# CELLTYPE_COLUMN should be replaced with actual column
Exp.setCellTypeColumn('cell_type') 
# Use 80% as train data and split the rest into a 50/50 split validation and testing
Exp.splitTrainTestValidation(train=0.8, rest=0.5)

# %% [markdown]
# Then we generate 500.000 training, 10.000 validation, and, 10.000 test samples.
# And load these into data loaders for use in training of the neural network.

# %%
Exp.generateTrainTestValidation(num_profiles=[500000,10000,10000], CD=[10,10])
# Load the profiles into data loaders
Exp.setupDataLoaders(batch_size=2500)
# Out:
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=500000)
# GENERATING VALIDATION DATASET (N=10000)
# GENERATING TEST DATASET (N=10000)

# %% [markdown]
# We then define the model (with default values) and use the first cuda device (cuda_id=1).

# %%
# Initialize Neural network-model and allocate it to the cuda_id specified
# Use 'cuda_id="cpu"' if you want to allocate it to a cpu
Exp.setupModel(cuda_id=0)
# Out:
# (CUDA) device is: cuda:0

# %% [markdown]
# We then train the network with 25 warm restarts, this means whenever we finish a training session we load the best model settings we have found so far back onto the model and continue from there in the next setting.

# %%
# do 25 warm restarts with decreasing learning rate
lr = 0.001 
best_error=None # no target error to beat in the beginning
for k in range(25):
    
    # Consider changing learning rate (lr) during run more dynamically
    if k >= 5:
        lr = 0.0005
    if k >= 10:
        lr = 0.0001
    if k >= 15:
        lr = 0.00005
    Exp.setupOptimizerAndCriterion(learning_rate = lr)
    # Train the experiment constructed by passing the experiment to the AntiSplodge training function 
    AS.train(Exp, save_file="ModelCheckpoint.pt", patience=5, best_loss=best_error) # For longer training, increase patience threshold
    best_error = AS.getMeanJSD(Exp, "validation") # set best error as the target error to beat
    
    print("Restart [{}] - JSDs".format(k),AS.getMeanJSD(Exp, "train"), AS.getMeanJSD(Exp, "validation"))
# Out:
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.02406 | (Valid): 0.01790 - (mean)JSD: (Train) 0.11571 | (Valid) 0.11644
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01703 | (Valid): 0.01679 - (mean)JSD: (Train) 0.10646 | (Valid) 0.10779
#
# Epoch: 003 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01590 | (Valid): 0.01553 - (mean)JSD: (Train) 0.10468 | (Valid) 0.10581
#
# Epoch: 004 | Epochs since last increase: 001
# Loss: (Train) 0.01523 | (Valid): 0.01537 - (mean)JSD: (Train) 0.10600 | (Valid) 0.10759
#
# Epoch: 005 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01474 | (Valid): 0.01505 - (mean)JSD: (Train) 0.10223 | (Valid) 0.10498
#
# Epoch: 006 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01441 | (Valid): 0.01433 - (mean)JSD: (Train) 0.09420 | (Valid) 0.09504
#
# Epoch: 007 | Epochs since last increase: 001
# Loss: (Train) 0.01409 | (Valid): 0.01482 - (mean)JSD: (Train) 0.09379 | (Valid) 0.09668
#
# Epoch: 008 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01402 | (Valid): 0.01403 - (mean)JSD: (Train) 0.09030 | (Valid) 0.09335
#
# Epoch: 009 | Epochs since last increase: 001
# Loss: (Train) 0.01373 | (Valid): 0.01397 - (mean)JSD: (Train) 0.09237 | (Valid) 0.09623
#
# Epoch: 010 | Epochs since last increase: 002
# Loss: (Train) 0.01361 | (Valid): 0.01447 - (mean)JSD: (Train) 0.09209 | (Valid) 0.09516
#
# Epoch: 011 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01355 | (Valid): 0.01353 - (mean)JSD: (Train) 0.08957 | (Valid) 0.09246
#
# Epoch: 012 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01335 | (Valid): 0.01348 - (mean)JSD: (Train) 0.08822 | (Valid) 0.09077
#
# Epoch: 013 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01318 | (Valid): 0.01338 - (mean)JSD: (Train) 0.08765 | (Valid) 0.09049
#
# Epoch: 014 | Epochs since last increase: 001
# Loss: (Train) 0.01323 | (Valid): 0.01338 - (mean)JSD: (Train) 0.08737 | (Valid) 0.09166
#
# Epoch: 015 | Epochs since last increase: 002
# Loss: (Train) 0.01308 | (Valid): 0.01348 - (mean)JSD: (Train) 0.08658 | (Valid) 0.09081
#
# Epoch: 016 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01304 | (Valid): 0.01349 - (mean)JSD: (Train) 0.08500 | (Valid) 0.08899
#
# Epoch: 017 | Epochs since last increase: 001
# Loss: (Train) 0.01286 | (Valid): 0.01333 - (mean)JSD: (Train) 0.08829 | (Valid) 0.09269
#
# Epoch: 018 | Epochs since last increase: 002
# Loss: (Train) 0.01280 | (Valid): 0.01340 - (mean)JSD: (Train) 0.08769 | (Valid) 0.09130
#
# Epoch: 019 | Epochs since last increase: 003
# Loss: (Train) 0.01278 | (Valid): 0.01334 - (mean)JSD: (Train) 0.08537 | (Valid) 0.08954
#
# Epoch: 020 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01268 | (Valid): 0.01285 - (mean)JSD: (Train) 0.08385 | (Valid) 0.08803
#
# Epoch: 021 | Epochs since last increase: 001
# Loss: (Train) 0.01272 | (Valid): 0.01315 - (mean)JSD: (Train) 0.08672 | (Valid) 0.09113
#
# Epoch: 022 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01261 | (Valid): 0.01271 - (mean)JSD: (Train) 0.08387 | (Valid) 0.08786
#
# Epoch: 023 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01247 | (Valid): 0.01298 - (mean)JSD: (Train) 0.08246 | (Valid) 0.08751
#
# Epoch: 024 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01244 | (Valid): 0.01276 - (mean)JSD: (Train) 0.08101 | (Valid) 0.08528
#
# Epoch: 025 | Epochs since last increase: 001
# Loss: (Train) 0.01232 | (Valid): 0.01295 - (mean)JSD: (Train) 0.08427 | (Valid) 0.08915
#
# Epoch: 026 | Epochs since last increase: 002
# Loss: (Train) 0.01227 | (Valid): 0.01264 - (mean)JSD: (Train) 0.08078 | (Valid) 0.08574
#
# Epoch: 027 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01227 | (Valid): 0.01240 - (mean)JSD: (Train) 0.08036 | (Valid) 0.08497
#
# Epoch: 028 | Epochs since last increase: 001
# Loss: (Train) 0.01221 | (Valid): 0.01253 - (mean)JSD: (Train) 0.08271 | (Valid) 0.08722
#
# Epoch: 029 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01212 | (Valid): 0.01209 - (mean)JSD: (Train) 0.07818 | (Valid) 0.08347
#
# Epoch: 030 | Epochs since last increase: 001
# Loss: (Train) 0.01202 | (Valid): 0.01250 - (mean)JSD: (Train) 0.08076 | (Valid) 0.08577
#
# Epoch: 031 | Epochs since last increase: 002
# Loss: (Train) 0.01204 | (Valid): 0.01296 - (mean)JSD: (Train) 0.08389 | (Valid) 0.08939
#
# Epoch: 032 | Epochs since last increase: 003
# Loss: (Train) 0.01199 | (Valid): 0.01261 - (mean)JSD: (Train) 0.08368 | (Valid) 0.08921
#
# Epoch: 033 | Epochs since last increase: 004
# Loss: (Train) 0.01194 | (Valid): 0.01232 - (mean)JSD: (Train) 0.08142 | (Valid) 0.08720
#
# Epoch: 034 | Epochs since last increase: 005
# Loss: (Train) 0.01194 | (Valid): 0.01225 - (mean)JSD: (Train) 0.07809 | (Valid) 0.08445
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 1097.11 (18.29 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [0] - JSDs 0.0781799753933141 0.08347195511076605
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01233 | (Valid): 0.01280 - (mean)JSD: (Train) 0.08184 | (Valid) 0.08691
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01206 | (Valid): 0.01216 - (mean)JSD: (Train) 0.08152 | (Valid) 0.08579
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01212 | (Valid): 0.01266 - (mean)JSD: (Train) 0.08113 | (Valid) 0.08720
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01199 | (Valid): 0.01255 - (mean)JSD: (Train) 0.08354 | (Valid) 0.08949
#
# Epoch: 005 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01190 | (Valid): 0.01213 - (mean)JSD: (Train) 0.07761 | (Valid) 0.08313
#
# Epoch: 006 | Epochs since last increase: 001
# Loss: (Train) 0.01188 | (Valid): 0.01227 - (mean)JSD: (Train) 0.08187 | (Valid) 0.08773
#
# Epoch: 007 | Epochs since last increase: 002
# Loss: (Train) 0.01179 | (Valid): 0.01210 - (mean)JSD: (Train) 0.07871 | (Valid) 0.08459
#
# Epoch: 008 | Epochs since last increase: 003
# Loss: (Train) 0.01175 | (Valid): 0.01224 - (mean)JSD: (Train) 0.07862 | (Valid) 0.08423
#
# Epoch: 009 | Epochs since last increase: 004
# Loss: (Train) 0.01169 | (Valid): 0.01220 - (mean)JSD: (Train) 0.08000 | (Valid) 0.08623
#
# Epoch: 010 | Epochs since last increase: 005
# Loss: (Train) 0.01168 | (Valid): 0.01224 - (mean)JSD: (Train) 0.07751 | (Valid) 0.08370
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 324.06 (5.40 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [1] - JSDs 0.07761261954272479 0.08313330346758878
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01206 | (Valid): 0.01236 - (mean)JSD: (Train) 0.08020 | (Valid) 0.08509
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01183 | (Valid): 0.01242 - (mean)JSD: (Train) 0.07955 | (Valid) 0.08518
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01183 | (Valid): 0.01235 - (mean)JSD: (Train) 0.07987 | (Valid) 0.08599
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01182 | (Valid): 0.01240 - (mean)JSD: (Train) 0.07896 | (Valid) 0.08548
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01168 | (Valid): 0.01209 - (mean)JSD: (Train) 0.07791 | (Valid) 0.08418
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01156 | (Valid): 0.01230 - (mean)JSD: (Train) 0.07992 | (Valid) 0.08612
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 193.54 (3.23 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [2] - JSDs 0.07761261954272479 0.08313330346758878
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01202 | (Valid): 0.01217 - (mean)JSD: (Train) 0.07846 | (Valid) 0.08417
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01183 | (Valid): 0.01235 - (mean)JSD: (Train) 0.08018 | (Valid) 0.08606
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01182 | (Valid): 0.01247 - (mean)JSD: (Train) 0.07945 | (Valid) 0.08588
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01177 | (Valid): 0.01210 - (mean)JSD: (Train) 0.08040 | (Valid) 0.08609
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01167 | (Valid): 0.01239 - (mean)JSD: (Train) 0.07740 | (Valid) 0.08450
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01162 | (Valid): 0.01263 - (mean)JSD: (Train) 0.08003 | (Valid) 0.08677
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 197.02 (3.28 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [3] - JSDs 0.07761261954272479 0.08313330346758878
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01204 | (Valid): 0.01211 - (mean)JSD: (Train) 0.07938 | (Valid) 0.08462
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01187 | (Valid): 0.01229 - (mean)JSD: (Train) 0.08078 | (Valid) 0.08734
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01179 | (Valid): 0.01217 - (mean)JSD: (Train) 0.07881 | (Valid) 0.08464
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01175 | (Valid): 0.01269 - (mean)JSD: (Train) 0.07950 | (Valid) 0.08584
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01168 | (Valid): 0.01260 - (mean)JSD: (Train) 0.07860 | (Valid) 0.08442
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01162 | (Valid): 0.01207 - (mean)JSD: (Train) 0.07707 | (Valid) 0.08375
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 197.83 (3.30 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [4] - JSDs 0.07761261954272479 0.08313330346758878
# Epoch: 001 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01141 | (Valid): 0.01170 - (mean)JSD: (Train) 0.07701 | (Valid) 0.08297
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01132 | (Valid): 0.01194 - (mean)JSD: (Train) 0.07506 | (Valid) 0.08238
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.01127 | (Valid): 0.01215 - (mean)JSD: (Train) 0.07638 | (Valid) 0.08287
#
# Epoch: 004 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01128 | (Valid): 0.01180 - (mean)JSD: (Train) 0.07582 | (Valid) 0.08219
#
# Epoch: 005 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01115 | (Valid): 0.01170 - (mean)JSD: (Train) 0.07505 | (Valid) 0.08162
#
# Epoch: 006 | Epochs since last increase: 001
# Loss: (Train) 0.01119 | (Valid): 0.01169 - (mean)JSD: (Train) 0.07547 | (Valid) 0.08240
#
# Epoch: 007 | Epochs since last increase: 002
# Loss: (Train) 0.01109 | (Valid): 0.01160 - (mean)JSD: (Train) 0.07560 | (Valid) 0.08279
#
# Epoch: 008 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01109 | (Valid): 0.01169 - (mean)JSD: (Train) 0.07374 | (Valid) 0.08118
#
# Epoch: 009 | Epochs since last increase: 001
# Loss: (Train) 0.01104 | (Valid): 0.01169 - (mean)JSD: (Train) 0.07447 | (Valid) 0.08160
#
# Epoch: 010 | Epochs since last increase: 002
# Loss: (Train) 0.01099 | (Valid): 0.01174 - (mean)JSD: (Train) 0.07416 | (Valid) 0.08139
#
# Epoch: 011 | Epochs since last increase: 003
# Loss: (Train) 0.01099 | (Valid): 0.01163 - (mean)JSD: (Train) 0.07357 | (Valid) 0.08139
#
# Epoch: 012 | Epochs since last increase: 004
# Loss: (Train) 0.01097 | (Valid): 0.01180 - (mean)JSD: (Train) 0.07519 | (Valid) 0.08359
#
# Epoch: 013 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01097 | (Valid): 0.01145 - (mean)JSD: (Train) 0.07313 | (Valid) 0.08104
#
# Epoch: 014 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01091 | (Valid): 0.01166 - (mean)JSD: (Train) 0.07265 | (Valid) 0.08054
#
# Epoch: 015 | Epochs since last increase: 001
# Loss: (Train) 0.01091 | (Valid): 0.01156 - (mean)JSD: (Train) 0.07434 | (Valid) 0.08151
#
# Epoch: 016 | Epochs since last increase: 002
# Loss: (Train) 0.01086 | (Valid): 0.01178 - (mean)JSD: (Train) 0.07430 | (Valid) 0.08314
#
# Epoch: 017 | Epochs since last increase: 003
# Loss: (Train) 0.01088 | (Valid): 0.01161 - (mean)JSD: (Train) 0.07290 | (Valid) 0.08125
#
# Epoch: 018 | Epochs since last increase: 004
# Loss: (Train) 0.01081 | (Valid): 0.01163 - (mean)JSD: (Train) 0.07347 | (Valid) 0.08218
#
# Epoch: 019 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01077 | (Valid): 0.01150 - (mean)JSD: (Train) 0.07137 | (Valid) 0.07982
#
# Epoch: 020 | Epochs since last increase: 001
# Loss: (Train) 0.01080 | (Valid): 0.01150 - (mean)JSD: (Train) 0.07336 | (Valid) 0.08115
#
# Epoch: 021 | Epochs since last increase: 002
# Loss: (Train) 0.01079 | (Valid): 0.01173 - (mean)JSD: (Train) 0.07452 | (Valid) 0.08372
#
# Epoch: 022 | Epochs since last increase: 003
# Loss: (Train) 0.01070 | (Valid): 0.01153 - (mean)JSD: (Train) 0.07259 | (Valid) 0.08138
#
# Epoch: 023 | Epochs since last increase: 004
# Loss: (Train) 0.01071 | (Valid): 0.01155 - (mean)JSD: (Train) 0.07177 | (Valid) 0.08107
#
# Epoch: 024 | Epochs since last increase: 005
# Loss: (Train) 0.01067 | (Valid): 0.01152 - (mean)JSD: (Train) 0.07414 | (Valid) 0.08314
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 799.08 (13.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [5] - JSDs 0.0713664292946016 0.07981690082481785
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01088 | (Valid): 0.01170 - (mean)JSD: (Train) 0.07515 | (Valid) 0.08375
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01078 | (Valid): 0.01157 - (mean)JSD: (Train) 0.07341 | (Valid) 0.08295
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01072 | (Valid): 0.01149 - (mean)JSD: (Train) 0.07215 | (Valid) 0.08105
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01077 | (Valid): 0.01155 - (mean)JSD: (Train) 0.07259 | (Valid) 0.08112
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01074 | (Valid): 0.01158 - (mean)JSD: (Train) 0.07350 | (Valid) 0.08232
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01073 | (Valid): 0.01153 - (mean)JSD: (Train) 0.07305 | (Valid) 0.08245
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.12 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [6] - JSDs 0.0713664292946016 0.07981690082481785
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01082 | (Valid): 0.01173 - (mean)JSD: (Train) 0.07355 | (Valid) 0.08261
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01074 | (Valid): 0.01156 - (mean)JSD: (Train) 0.07264 | (Valid) 0.08211
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01076 | (Valid): 0.01165 - (mean)JSD: (Train) 0.07365 | (Valid) 0.08254
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01072 | (Valid): 0.01147 - (mean)JSD: (Train) 0.07294 | (Valid) 0.08142
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01068 | (Valid): 0.01144 - (mean)JSD: (Train) 0.07117 | (Valid) 0.08009
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01068 | (Valid): 0.01167 - (mean)JSD: (Train) 0.07324 | (Valid) 0.08300
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.62 (3.33 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [7] - JSDs 0.0713664292946016 0.07981690082481785
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01084 | (Valid): 0.01161 - (mean)JSD: (Train) 0.07457 | (Valid) 0.08288
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01077 | (Valid): 0.01156 - (mean)JSD: (Train) 0.07334 | (Valid) 0.08184
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01074 | (Valid): 0.01148 - (mean)JSD: (Train) 0.07225 | (Valid) 0.08146
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01072 | (Valid): 0.01154 - (mean)JSD: (Train) 0.07266 | (Valid) 0.08136
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01072 | (Valid): 0.01155 - (mean)JSD: (Train) 0.07247 | (Valid) 0.08171
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01063 | (Valid): 0.01146 - (mean)JSD: (Train) 0.07174 | (Valid) 0.08070
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 198.68 (3.31 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [8] - JSDs 0.0713664292946016 0.07981690082481785
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01087 | (Valid): 0.01160 - (mean)JSD: (Train) 0.07347 | (Valid) 0.08227
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01078 | (Valid): 0.01144 - (mean)JSD: (Train) 0.07207 | (Valid) 0.08029
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01075 | (Valid): 0.01150 - (mean)JSD: (Train) 0.07205 | (Valid) 0.08094
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01074 | (Valid): 0.01180 - (mean)JSD: (Train) 0.07476 | (Valid) 0.08463
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01069 | (Valid): 0.01148 - (mean)JSD: (Train) 0.07224 | (Valid) 0.08138
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01069 | (Valid): 0.01152 - (mean)JSD: (Train) 0.07316 | (Valid) 0.08237
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.28 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [9] - JSDs 0.0713664292946016 0.07981690082481785
# Epoch: 001 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01027 | (Valid): 0.01109 - (mean)JSD: (Train) 0.07034 | (Valid) 0.07972
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01022 | (Valid): 0.01113 - (mean)JSD: (Train) 0.06905 | (Valid) 0.07874
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.01020 | (Valid): 0.01115 - (mean)JSD: (Train) 0.06917 | (Valid) 0.07933
#
# Epoch: 004 | Epochs since last increase: 002
# Loss: (Train) 0.01020 | (Valid): 0.01113 - (mean)JSD: (Train) 0.06968 | (Valid) 0.07979
#
# Epoch: 005 | Epochs since last increase: 003
# Loss: (Train) 0.01017 | (Valid): 0.01109 - (mean)JSD: (Train) 0.06862 | (Valid) 0.07877
#
# Epoch: 006 | Epochs since last increase: 004
# Loss: (Train) 0.01015 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06949 | (Valid) 0.07966
#
# Epoch: 007 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01015 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06827 | (Valid) 0.07821
#
# Epoch: 008 | Epochs since last increase: 001
# Loss: (Train) 0.01013 | (Valid): 0.01112 - (mean)JSD: (Train) 0.06975 | (Valid) 0.07972
#
# Epoch: 009 | Epochs since last increase: 002
# Loss: (Train) 0.01012 | (Valid): 0.01114 - (mean)JSD: (Train) 0.06925 | (Valid) 0.07974
#
# Epoch: 010 | Epochs since last increase: 003
# Loss: (Train) 0.01013 | (Valid): 0.01109 - (mean)JSD: (Train) 0.06898 | (Valid) 0.07955
#
# Epoch: 011 | Epochs since last increase: 004
# Loss: (Train) 0.01007 | (Valid): 0.01114 - (mean)JSD: (Train) 0.06949 | (Valid) 0.08021
#
# Epoch: 012 | Epochs since last increase: 005
# Loss: (Train) 0.01011 | (Valid): 0.01110 - (mean)JSD: (Train) 0.06895 | (Valid) 0.07953
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 394.37 (6.57 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [10] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01015 | (Valid): 0.01109 - (mean)JSD: (Train) 0.06829 | (Valid) 0.07841
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01013 | (Valid): 0.01110 - (mean)JSD: (Train) 0.06924 | (Valid) 0.07970
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01011 | (Valid): 0.01110 - (mean)JSD: (Train) 0.06964 | (Valid) 0.08007
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01009 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06850 | (Valid) 0.07881
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01010 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06848 | (Valid) 0.07900
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01008 | (Valid): 0.01109 - (mean)JSD: (Train) 0.06826 | (Valid) 0.07863
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 196.94 (3.28 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [11] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01015 | (Valid): 0.01114 - (mean)JSD: (Train) 0.06888 | (Valid) 0.07939
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01013 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06835 | (Valid) 0.07856
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01011 | (Valid): 0.01110 - (mean)JSD: (Train) 0.06804 | (Valid) 0.07865
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01010 | (Valid): 0.01113 - (mean)JSD: (Train) 0.06911 | (Valid) 0.07955
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01010 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06920 | (Valid) 0.07954
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01009 | (Valid): 0.01117 - (mean)JSD: (Train) 0.06997 | (Valid) 0.08061
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 198.96 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [12] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01012 | (Valid): 0.01111 - (mean)JSD: (Train) 0.06842 | (Valid) 0.07852
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01012 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06969 | (Valid) 0.07986
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01012 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06894 | (Valid) 0.07913
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01010 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06860 | (Valid) 0.07868
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01008 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06848 | (Valid) 0.07903
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01009 | (Valid): 0.01109 - (mean)JSD: (Train) 0.06818 | (Valid) 0.07883
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.34 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [13] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01015 | (Valid): 0.01109 - (mean)JSD: (Train) 0.06881 | (Valid) 0.07926
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01012 | (Valid): 0.01111 - (mean)JSD: (Train) 0.06850 | (Valid) 0.07880
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01011 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06817 | (Valid) 0.07829
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01013 | (Valid): 0.01113 - (mean)JSD: (Train) 0.06827 | (Valid) 0.07866
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01011 | (Valid): 0.01107 - (mean)JSD: (Train) 0.06938 | (Valid) 0.07959
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01012 | (Valid): 0.01111 - (mean)JSD: (Train) 0.06851 | (Valid) 0.07920
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 198.95 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [14] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01006 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06828 | (Valid) 0.07879
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01005 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06871 | (Valid) 0.07930
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01004 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06806 | (Valid) 0.07868
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01003 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06817 | (Valid) 0.07882
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01003 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06812 | (Valid) 0.07885
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01002 | (Valid): 0.01101 - (mean)JSD: (Train) 0.06824 | (Valid) 0.07866
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.61 (3.33 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [15] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01007 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06860 | (Valid) 0.07909
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01004 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06778 | (Valid) 0.07825
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01003 | (Valid): 0.01101 - (mean)JSD: (Train) 0.06805 | (Valid) 0.07834
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01003 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06811 | (Valid) 0.07860
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01003 | (Valid): 0.01101 - (mean)JSD: (Train) 0.06782 | (Valid) 0.07827
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01002 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06803 | (Valid) 0.07866
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.34 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [16] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01005 | (Valid): 0.01101 - (mean)JSD: (Train) 0.06796 | (Valid) 0.07827
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01004 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06798 | (Valid) 0.07828
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01004 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06834 | (Valid) 0.07874
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01004 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06784 | (Valid) 0.07835
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01001 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06809 | (Valid) 0.07880
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01000 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06815 | (Valid) 0.07880
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 200.27 (3.34 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [17] - JSDs 0.06827267522789586 0.07820636961783578
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01005 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06828 | (Valid) 0.07877
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01005 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06833 | (Valid) 0.07887
#
# Epoch: 003 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01005 | (Valid): 0.01099 - (mean)JSD: (Train) 0.06784 | (Valid) 0.07801
#
# Epoch: 004 | Epochs since last increase: 001
# Loss: (Train) 0.01004 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06805 | (Valid) 0.07861
#
# Epoch: 005 | Epochs since last increase: 002
# Loss: (Train) 0.01002 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06844 | (Valid) 0.07907
#
# Epoch: 006 | Epochs since last increase: 003
# Loss: (Train) 0.01004 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06774 | (Valid) 0.07836
#
# Epoch: 007 | Epochs since last increase: 004
# Loss: (Train) 0.01002 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06845 | (Valid) 0.07904
#
# Epoch: 008 | Epochs since last increase: 005
# Loss: (Train) 0.01001 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06816 | (Valid) 0.07880
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 266.63 (4.44 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [18] - JSDs 0.06784003396816517 0.07800503775816546
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01003 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06870 | (Valid) 0.07935
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01002 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06826 | (Valid) 0.07902
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01004 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06814 | (Valid) 0.07868
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01000 | (Valid): 0.01100 - (mean)JSD: (Train) 0.06858 | (Valid) 0.07907
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00999 | (Valid): 0.01099 - (mean)JSD: (Train) 0.06809 | (Valid) 0.07854
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01002 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06830 | (Valid) 0.07895
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.32 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [19] - JSDs 0.06784003396816517 0.07800503775816546
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01003 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06834 | (Valid) 0.07883
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01003 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06792 | (Valid) 0.07851
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01002 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06878 | (Valid) 0.07940
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01001 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06784 | (Valid) 0.07841
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01004 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06816 | (Valid) 0.07881
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01001 | (Valid): 0.01101 - (mean)JSD: (Train) 0.06840 | (Valid) 0.07899
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 199.21 (3.32 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [20] - JSDs 0.06784003396816517 0.07800503775816546
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01005 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06873 | (Valid) 0.07926
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01002 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06857 | (Valid) 0.07916
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01001 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06804 | (Valid) 0.07871
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01002 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06813 | (Valid) 0.07886
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01001 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06805 | (Valid) 0.07861
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01000 | (Valid): 0.01101 - (mean)JSD: (Train) 0.06781 | (Valid) 0.07853
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 202.27 (3.37 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [21] - JSDs 0.06784003396816517 0.07800503775816546
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01004 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06818 | (Valid) 0.07876
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01004 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06831 | (Valid) 0.07891
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01002 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06827 | (Valid) 0.07900
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01002 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06869 | (Valid) 0.07926
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01003 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06847 | (Valid) 0.07921
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01001 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06874 | (Valid) 0.07949
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 231.64 (3.86 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [22] - JSDs 0.06784003396816517 0.07800503775816546
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01002 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06840 | (Valid) 0.07884
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01003 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06843 | (Valid) 0.07917
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01003 | (Valid): 0.01106 - (mean)JSD: (Train) 0.06858 | (Valid) 0.07924
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01000 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06821 | (Valid) 0.07892
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01000 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06833 | (Valid) 0.07902
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01002 | (Valid): 0.01108 - (mean)JSD: (Train) 0.06852 | (Valid) 0.07943
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 233.92 (3.90 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [23] - JSDs 0.06784003396816517 0.07800503775816546
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01006 | (Valid): 0.01104 - (mean)JSD: (Train) 0.06805 | (Valid) 0.07852
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01003 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06803 | (Valid) 0.07872
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01002 | (Valid): 0.01102 - (mean)JSD: (Train) 0.06780 | (Valid) 0.07836
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01000 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06773 | (Valid) 0.07836
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01000 | (Valid): 0.01103 - (mean)JSD: (Train) 0.06825 | (Valid) 0.07896
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01000 | (Valid): 0.01105 - (mean)JSD: (Train) 0.06835 | (Valid) 0.07900
#
# Finished training (checkpoint saved in: ModelCheckpoint.pt)
# Time elapsed: 239.28 (3.99 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint.pt
# Restart [24] - JSDs 0.06784003396816517 0.07800503775816546

# %% [markdown]
# In the end, we have a very satisfactory JSD of 7.974%!

# %%
print("Test accuracy:", "{:2f}%".format(AS.getMeanJSD(Exp, "test")*100))
# Out:
# Test accuracy: 7.974431%

# %% [markdown]
# ### Breakdown of the training
# Below are the most useful prints from the training above:
#
# Time elapsed: 1097.11 (18.29 Minutes)
# Restart [0] - JSDs 0.0781799753933141 0.08347195511076605
#
# Time elapsed: 324.06 (5.40 Minutes)
# Restart [1] - JSDs 0.07761261954272479 0.08313330346758878
#
# Time elapsed: 193.54 (3.23 Minutes)
# Restart [2] - JSDs 0.07761261954272479 0.08313330346758878
#
# Time elapsed: 197.02 (3.28 Minutes)
# Restart [3] - JSDs 0.07761261954272479 0.08313330346758878
#
# Time elapsed: 197.83 (3.30 Minutes)
# Restart [4] - JSDs 0.07761261954272479 0.08313330346758878
#
# Time elapsed: 799.08 (13.32 Minutes)
# Restart [5] - JSDs 0.0713664292946016 0.07981690082481785
#
# Time elapsed: 199.12 (3.32 Minutes)
# Restart [6] - JSDs 0.0713664292946016 0.07981690082481785
#
# Time elapsed: 199.62 (3.33 Minutes)
# Restart [7] - JSDs 0.0713664292946016 0.07981690082481785
#
# Time elapsed: 198.68 (3.31 Minutes)
# Restart [8] - JSDs 0.0713664292946016 0.07981690082481785
#
# Time elapsed: 199.28 (3.32 Minutes)
# Restart [9] - JSDs 0.0713664292946016 0.07981690082481785
#
# Time elapsed: 394.37 (6.57 Minutes)
# Restart [10] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 196.94 (3.28 Minutes)
# Restart [11] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 198.96 (3.32 Minutes)
# Restart [12] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 199.34 (3.32 Minutes)
# Restart [13] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 198.95 (3.32 Minutes)
# Restart [14] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 199.61 (3.33 Minutes)
# Restart [15] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 199.34 (3.32 Minutes)
# Restart [16] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 200.27 (3.34 Minutes)
# Restart [17] - JSDs 0.06827267522789586 0.07820636961783578
#
# Time elapsed: 266.63 (4.44 Minutes)
# Restart [18] - JSDs 0.06784003396816517 0.07800503775816546
#
# Time elapsed: 199.32 (3.32 Minutes)
# Restart [19] - JSDs 0.06784003396816517 0.07800503775816546
#
# Time elapsed: 199.21 (3.32 Minutes)
# Restart [20] - JSDs 0.06784003396816517 0.07800503775816546
#
# Time elapsed: 202.27 (3.37 Minutes)
# Restart [21] - JSDs 0.06784003396816517 0.07800503775816546
#
# Time elapsed: 231.64 (3.86 Minutes)
# Restart [22] - JSDs 0.06784003396816517 0.07800503775816546
#
# Time elapsed: 233.92 (3.90 Minutes)
# Restart [23] - JSDs 0.06784003396816517 0.07800503775816546
#
# Time elapsed: 239.28 (3.99 Minutes)
# Restart [24] - JSDs 0.06784003396816517 0.07800503775816546
#
# Already at the first training session, we have a validation JSD of 0.0834, then at:
#
# [1] 0.0831,
# [5] 0.0798,
# [10] 0.0782,
# [18] 0.0780 (18 is the last improvement)
#
# The numbers listed above are the mean validation JSDs, actually already at the first step we had a very satisfactory JSD, but we reduced the JSD by approximately 0.5% overall by doing this extra training, all of this took approximately 1.5 hours, so all in all a very neat tool.
