# %% [markdown]
# ### AntiSplodge 10-fold cross validation example
# This notebook relies on heavily on the minimal example notebook (https://github.com/HealthML/AntiSplodge/blob/main/AntiSplodge_minimal_example.ipynb).
#
# If something related to AntiSplodge is unclear, please refer to that notebook.
#
# First:
# Import the packages we need for this, remember to install them with "pip install PACKAGE" in your terminal.

# %%
import anndata as ann
import scanpy as sc
import numpy as np

import antisplodge as AS

from collections import Counter

# %% [markdown]
# After importing the required packages, load the dataset into memory, remember to have the dataset in the same folder as the notebook.
#
# You can download the dataset direcly from https://cellgeni.cog.sanger.ac.uk/heartcellatlas/data/global_raw.h5ad.

# %%
SC = ann.read("global_raw.h5ad")

# %%
SC.obs
# Out:
#                                     NRP age_group     cell_source  \
# AAACCCAAGAACGCGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAAGCAAACAT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAAGCTACTGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCAGTACCGCGT-1-H0015_apex        No     50-55  Harvard-Nuclei
# AAACCCATCAAACCCA-1-H0015_apex        No     50-55  Harvard-Nuclei
# ...                                 ...       ...             ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCCTACCAC-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGACGCTG-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862  Yes     60-65     Sanger-CD45
#
#                                                     cell_type donor  gender  \
# AAACCCAAGAACGCGT-1-H0015_apex             Smooth_muscle_cells    H5  Female
# AAACCCAAGCAAACAT-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# AAACCCAAGCTACTGT-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# AAACCCAGTACCGCGT-1-H0015_apex                       Pericytes    H5  Female
# AAACCCATCAAACCCA-1-H0015_apex       Ventricular_Cardiomyocyte    H5  Female
# ...                                                       ...   ...     ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCCTACCAC-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGACGCTG-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862                Endothelial   D11  Female
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862                Endothelial   D11  Female
#
#                                     n_counts  n_genes  percent_mito  \
# AAACCCAAGAACGCGT-1-H0015_apex          688.0      480      0.004360
# AAACCCAAGCAAACAT-1-H0015_apex         3216.0     1365      0.000933
# AAACCCAAGCTACTGT-1-H0015_apex         3182.0     1521      0.000943
# AAACCCAGTACCGCGT-1-H0015_apex         1202.0      726      0.000832
# AAACCCATCAAACCCA-1-H0015_apex         3804.0     1584      0.000263
# ...                                      ...      ...           ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862    1619.0      904      0.087708
# TTTGTTGTCCTACCAC-1-HCAHeart8102862    1186.0      692      0.126476
# TTTGTTGTCGACGCTG-1-HCAHeart8102862    1672.0      847      0.145335
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862    4676.0     1925      0.163388
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862    3144.0     1422      0.097010
#
#                                     percent_ribo region           sample  \
# AAACCCAAGAACGCGT-1-H0015_apex           0.002907     AX       H0015_apex
# AAACCCAAGCAAACAT-1-H0015_apex           0.001244     AX       H0015_apex
# AAACCCAAGCTACTGT-1-H0015_apex           0.002200     AX       H0015_apex
# AAACCCAGTACCGCGT-1-H0015_apex           0.000000     AX       H0015_apex
# AAACCCATCAAACCCA-1-H0015_apex           0.001314     AX       H0015_apex
# ...                                          ...    ...              ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862      0.024707     AX  HCAHeart8102862
# TTTGTTGTCCTACCAC-1-HCAHeart8102862      0.015177     AX  HCAHeart8102862
# TTTGTTGTCGACGCTG-1-HCAHeart8102862      0.044258     AX  HCAHeart8102862
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862      0.044482     AX  HCAHeart8102862
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862      0.026081     AX  HCAHeart8102862
#
#                                     scrublet_score  source type version  \
# AAACCCAAGAACGCGT-1-H0015_apex             0.035917  Nuclei  DBD      V3
# AAACCCAAGCAAACAT-1-H0015_apex             0.147122  Nuclei  DBD      V3
# AAACCCAAGCTACTGT-1-H0015_apex             0.185751  Nuclei  DBD      V3
# AAACCCAGTACCGCGT-1-H0015_apex             0.035917  Nuclei  DBD      V3
# AAACCCATCAAACCCA-1-H0015_apex             0.108062  Nuclei  DBD      V3
# ...                                            ...     ...  ...     ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862        0.108062   CD45+  DCD      V3
# TTTGTTGTCCTACCAC-1-HCAHeart8102862        0.085546   CD45+  DCD      V3
# TTTGTTGTCGACGCTG-1-HCAHeart8102862        0.113475   CD45+  DCD      V3
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862        0.042770   CD45+  DCD      V3
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862        0.147122   CD45+  DCD      V3
#
#                                    cell_states Used
# AAACCCAAGAACGCGT-1-H0015_apex       SMC1_basic  Yes
# AAACCCAAGCAAACAT-1-H0015_apex             vCM1  Yes
# AAACCCAAGCTACTGT-1-H0015_apex             vCM1  Yes
# AAACCCAGTACCGCGT-1-H0015_apex        PC2_atria  Yes
# AAACCCATCAAACCCA-1-H0015_apex             vCM2  Yes
# ...                                        ...  ...
# TTTGTTGTCATACGGT-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCCTACCAC-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCGACGCTG-1-HCAHeart8102862     EC1_cap  Yes
# TTTGTTGTCGGCTGAC-1-HCAHeart8102862     EC5_art  Yes
# TTTGTTGTCGGTGTTA-1-HCAHeart8102862  EC4_immune  Yes
#
# [486134 rows x 18 columns]

# %% [markdown]
# After we have loaded the dataset into memory, we remove all cells that stems from other than Nuclei sequencing ('source'), only use a specific technology to remove technology-based batch effects ('cell_source'), and, remove cell types that are defined as 'doublets' or 'NotAssigned'.

# %%
SC = SC[SC.obs['source'] == 'Nuclei']
SC = SC[SC.obs['cell_source'] == 'Harvard-Nuclei']
SC = SC[~SC.obs['cell_type'].isin(['doublets', 'NotAssigned'])]

# %% [markdown]
# Let us look at the number of cells remaining (N=163959)

# %%
SC
# Out:
# View of AnnData object with n_obs × n_vars = 163959 × 33538
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45'
#     uns: 'cell_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ### Find marker genes
# Because of the high number of genes (N=33538), we want to reduce the set of genes to a smaller one in order to speed up training and reduce memory footprint. But it would work with all the genes, but the time to get an as good model will be a lot higher.
#
# However, before we look for marker genes, we scale all profiles to 1 using scanpy's function normalize_total, as shown below:

# %%
sc.pp.normalize_total(SC, target_sum=1)
# Out:
# /home/jel/.local/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %% [markdown]
# We now use the marker genes that can be found by running the minimal example notebook, we have hardcoded them below.

# %%
import pandas as pd

use_genes = list(pd.read_csv("marker_genes.csv")["0"])
use_genes
# Out:
# ['ABCA6',
#  'ABCA8',
#  'ABCA9',
#  'ABCA9-AS1',
#  'ABCC1',
#  'ABCC9',
#  'ABI1',
#  'ABI3BP',
#  'ABL1',
#  'ABTB2',
#  'AC003991.1',
#  'AC005037.1',
#  'AC005358.1',
#  'AC005699.1',
#  'AC007319.1',
#  'AC008056.1',
#  'AC008250.1',
#  'AC009264.1',
#  'AC010609.1',
#  'AC011369.1',
#  'AC011389.1',
#  'AC012636.1',
#  'AC013640.1',
#  'AC013652.1',
#  'AC015712.2',
#  'AC016766.1',
#  'AC016831.7',
#  'AC017002.5',
#  'AC018464.1',
#  'AC018742.1',
#  'AC019197.1',
#  'AC020637.1',
#  'AC022034.2',
#  'AC022075.1',
#  'AC027097.2',
#  'AC058822.1',
#  'AC068234.2',
#  'AC079336.4',
#  'AC084357.2',
#  'AC091057.6',
#  'AC091691.2',
#  'AC092114.1',
#  'AC092164.1',
#  'AC092567.1',
#  'AC092683.1',
#  'AC098617.1',
#  'AC100803.3',
#  'AC109587.1',
#  'AC109779.1',
#  'AC113386.1',
#  'AC114760.2',
#  'AC114763.1',
#  'AC120193.1',
#  'AC130650.1',
#  'AC140912.1',
#  'ACACB',
#  'ACAP1',
#  'ACKR1',
#  'ACLY',
#  'ACSL1',
#  'ACSL4',
#  'ACSM1',
#  'ACSM3',
#  'ACSS2',
#  'ACTA1',
#  'ACTB',
#  'ACTC1',
#  'ACTN4',
#  'ACVR1C',
#  'ADAM19',
#  'ADAM28',
#  'ADAMTS12',
#  'ADAMTS2',
#  'ADAMTS4',
#  'ADAMTS9',
#  'ADAMTSL1',
#  'ADAP2',
#  'ADARB2',
#  'ADCY3',
#  'ADCY4',
#  'ADD3',
#  'ADGRB3',
#  'ADGRD1',
#  'ADGRF5',
#  'ADGRL3',
#  'ADH1B',
#  'ADIPOQ',
#  'ADIPOR2',
#  'ADIRF',
#  'ADK',
#  'AFAP1L1',
#  'AFDN',
#  'AFF3',
#  'AGAP1',
#  'AGAP2',
#  'AGBL1',
#  'AGBL4',
#  'AGL',
#  'AGPAT2',
#  'AGT',
#  'AHCTF1',
#  'AHCYL2',
#  'AIFM1',
#  'AKAP12',
#  'AKAP6',
#  'AL034397.3',
#  'AL109930.1',
#  'AL117190.2',
#  'AL132671.2',
#  'AL138828.1',
#  'AL139383.1',
#  'AL139807.1',
#  'AL157871.4',
#  'AL450384.2',
#  'ALCAM',
#  'ALDH1A2',
#  'ALKBH3',
#  'AMPD3',
#  'ANAPC5',
#  'ANGPTL1',
#  'ANGPTL4',
#  'ANK2',
#  'ANK3',
#  'ANKRD1',
#  'ANKRD2',
#  'ANKRD44',
#  'ANKRD45',
#  'ANKS1B',
#  'ANKUB1',
#  'ANLN',
#  'ANO1',
#  'ANO2',
#  'ANXA1',
#  'AP000561.1',
#  'AP001021.2',
#  'AP001825.1',
#  'AP002518.2',
#  'AP002989.1',
#  'AP003108.2',
#  'APBB1IP',
#  'APCDD1',
#  'APOD',
#  'APPBP2',
#  'AQP1',
#  'AQP7',
#  'ARAP2',
#  'ARGLU1',
#  'ARHGAP1',
#  'ARHGAP15',
#  'ARHGAP18',
#  'ARHGAP21',
#  'ARHGAP24',
#  'ARHGAP31',
#  'ARID5B',
#  'ARL15',
#  'ARMH4',
#  'ARPC3',
#  'ASAP1',
#  'ASB11',
#  'ASPH',
#  'ASPN',
#  'ASTN2',
#  'ASXL2',
#  'ATF3',
#  'ATF6',
#  'ATG7',
#  'ATP10A',
#  'ATP1A2',
#  'ATP2B1',
#  'ATP2B4',
#  'ATRNL1',
#  'B2M',
#  'B3GLCT',
#  'B4GALT5',
#  'BACH1',
#  'BACH2',
#  'BANP',
#  'BBX',
#  'BCKDHB',
#  'BCL11B',
#  'BCL2',
#  'BCL6',
#  'BCO2',
#  'BHLHE40',
#  'BICC1',
#  'BICD1',
#  'BICDL1',
#  'BMP2K',
#  'BMPR1B',
#  'BMPR2',
#  'BMS1P14',
#  'BNC2',
#  'BOD1L1',
#  'BRCA1',
#  'BRCA2',
#  'BRD3',
#  'BRIP1',
#  'BST2',
#  'BTBD9',
#  'BTG2',
#  'BTNL9',
#  'C14orf180',
#  'C1QC',
#  'C1R',
#  'C2CD2',
#  'C3',
#  'C6',
#  'C7',
#  'CA1',
#  'CA4',
#  'CACNA2D3',
#  'CADM1',
#  'CADM2',
#  'CADPS',
#  'CALD1',
#  'CALM2',
#  'CAMK1D',
#  'CARD11',
#  'CARD8',
#  'CARMIL1',
#  'CARMN',
#  'CASQ2',
#  'CAV1',
#  'CAV2',
#  'CC2D2B',
#  'CCDC102B',
#  'CCDC18',
#  'CCDC3',
#  'CCDC80',
#  'CCDC88A',
#  'CCL2',
#  'CCL21',
#  'CCND3',
#  'CCNH',
#  'CCSER1',
#  'CD14',
#  'CD163',
#  'CD200',
#  'CD247',
#  'CD36',
#  'CD47',
#  'CD68',
#  'CD69',
#  'CD74',
#  'CD86',
#  'CD9',
#  'CDC42BPA',
#  'CDC42BPB',
#  'CDC42EP4',
#  'CDH13',
#  'CDH19',
#  'CDH6',
#  'CDK13',
#  'CDK15',
#  'CDKN1A',
#  'CDON',
#  'CELF2',
#  'CEMIP2',
#  'CENPK',
#  'CENPP',
#  'CEP128',
#  'CEP350',
#  'CEP95',
#  'CFH',
#  'CFLAR',
#  'CHD9',
#  'CHL1',
#  'CHRM3',
#  'CHST11',
#  'CHSY3',
#  'CKMT2',
#  'CKMT2-AS1',
#  'CLASP2',
#  'CLDN1',
#  'CLDN5',
#  'CLEC11A',
#  'CLEC2D',
#  'CLEC7A',
#  'CLIC4',
#  'CLIC5',
#  'CLK1',
#  'CLMN',
#  'CLMP',
#  'CLSPN',
#  'CLSTN2',
#  'CMIP',
#  'CMTM6',
#  'CMTM8',
#  'CNGA1',
#  'CNOT6L',
#  'CNR1',
#  'CNTN4',
#  'CNTNAP2',
#  'COBLL1',
#  'COL12A1',
#  'COL14A1',
#  'COL1A1',
#  'COL1A2',
#  'COL21A1',
#  'COL23A1',
#  'COL24A1',
#  'COL27A1',
#  'COL4A1',
#  'COL4A2',
#  'COL4A3',
#  'COL4A4',
#  'COL4A5',
#  'COL5A1',
#  'COL5A2',
#  'COL6A3',
#  'COL6A6',
#  'COL8A1',
#  'COL9A3',
#  'COLGALT2',
#  'COMT',
#  'COQ10A',
#  'CORO2B',
#  'COX4I2',
#  'CPA3',
#  'CPAMD8',
#  'CPED1',
#  'CPLX3',
#  'CPM',
#  'CPNE8',
#  'CPXM2',
#  'CRADD',
#  'CREB5',
#  'CRIM1',
#  'CROT',
#  'CSDC2',
#  'CSRNP3',
#  'CSRP3',
#  'CST3',
#  'CTDSPL',
#  'CTNNA1',
#  'CTNNA3',
#  'CTNND2',
#  'CTSB',
#  'CTSC',
#  'CXADR',
#  'CXCL1',
#  'CXCL2',
#  'CYB5R3',
#  'CYP1B1',
#  'CYP4Z1',
#  'CYR61',
#  'CYTIP',
#  'CYTOR',
#  'CYYR1',
#  'DAPK1',
#  'DAPK2',
#  'DCBLD1',
#  'DCLK1',
#  'DCN',
#  'DDAH1',
#  'DDR2',
#  'DDX17',
#  'DDX5',
#  'DECR1',
#  'DEDD',
#  'DENND1A',
#  'DES',
#  'DGKH',
#  'DGLUCY',
#  'DIAPH3',
#  'DISC1',
#  'DKK3',
#  'DLC1',
#  'DLG4',
#  'DNAJA1',
#  'DNAJC1',
#  'DNAJC6',
#  'DNM3',
#  'DOCK10',
#  'DOCK3',
#  'DOCK4',
#  'DOCK6',
#  'DOCK8',
#  'DOCK9',
#  'DPF3',
#  'DPP6',
#  'DPYD',
#  'DPYSL2',
#  'DST',
#  'DSTN',
#  'DTNB',
#  'DTX3',
#  'DUSP1',
#  'DYM',
#  'DYNC1I1',
#  'EBF1',
#  'ECE1',
#  'ECHDC2',
#  'EDC3',
#  'EDF1',
#  'EDNRA',
#  'EFEMP1',
#  'EFL1',
#  'EFNA5',
#  'EGFL7',
#  'EGFR',
#  'EHBP1',
#  'EIF1B',
#  'EIF2AK3',
#  'EIF3A',
#  'EIF4A1',
#  'ELL2',
#  'ELMO1',
#  'ELN',
#  'EMC10',
#  'EMCN',
#  'EMP1',
#  'ENG',
#  'ENOSF1',
#  'ENOX1',
#  'ENPEP',
#  'ENTPD1',
#  'ENTPD1-AS1',
#  'EPAS1',
#  'EPB41L2',
#  'EPG5',
#  'EPHA4',
#  'EPHB1',
#  'ERBB4',
#  'ERBIN',
#  'ERH',
#  'ERICH1',
#  'ERRFI1',
#  'ESR2',
#  'ETFB',
#  'EVA1C',
#  'EVI5',
#  'EVL',
#  'EWSR1',
#  'EXOC4',
#  'EXOC6B',
#  'EXT1',
#  'EXTL3',
#  'EYA4',
#  'EZR',
#  'F13A1',
#  'FABP4',
#  'FABP5',
#  'FAF1',
#  'FAM107B',
#  'FAM111B',
#  'FAM126B',
#  'FAM129A',
#  'FAM13A',
#  'FAM155A',
#  'FAM189A2',
#  'FAM198B-AS1',
#  'FAM45A',
#  'FAM49B',
#  'FAR2',
#  'FASN',
#  'FAT3',
#  'FBLN2',
#  'FBLN5',
#  'FBN1',
#  'FBXL13',
#  'FBXL7',
#  'FBXO21',
#  'FBXW7',
#  'FCER1G',
#  'FCHSD2',
#  'FER',
#  'FEZ2',
#  'FGD4',
#  'FGF14',
#  'FGF7',
#  'FGFR1',
#  'FHIT',
#  'FHL2',
#  'FHL5',
#  'FHOD3',
#  'FIGN',
#  'FILIP1L',
#  'FKBP5',
#  'FLI1',
#  'FLNA',
#  'FLNC-AS1',
#  'FLT1',
#  'FMN1',
#  'FMO2',
#  'FN1',
#  'FN3K',
#  'FNBP1',
#  'FNDC3B',
#  'FOS',
#  'FOSB',
#  'FOXO1',
#  'FOXO3',
#  'FOXP2',
#  'FRAS1',
#  'FRK',
#  'FRMD4A',
#  'FRMD4B',
#  'FRMD5',
#  'FRMPD2',
#  'FSTL1',
#  'FTH1',
#  'FUT8',
#  'FYB1',
#  'FYN',
#  'G0S2',
#  'GABPB1-AS1',
#  'GALK2',
#  'GALNT17',
#  'GALNT18',
#  'GAPVD1',
#  'GAS7',
#  'GBE1',
#  'GCNT2',
#  'GDAP1',
#  'GFPT2',
#  'GGT5',
#  'GHR',
#  'GIMAP8',
#  'GLCCI1',
#  'GLIS3',
#  'GMDS',
#  'GNA12',
#  'GNA14-AS1',
#  'GNAQ',
#  'GNLY',
#  'GOLGA4',
#  'GPAM',
#  'GPATCH8',
#  'GPBP1',
#  'GPC6',
#  'GPM6A',
#  'GPM6B',
#  'GPR155',
#  'GPR20',
#  'GPR34',
#  'GPRIN3',
#  'GPX3',
#  'GRAMD1B',
#  'GRB10',
#  'GREB1L',
#  'GRIK2',
#  'GRIP1',
#  'GRIP2',
#  'GRK3',
#  'GSE1',
#  'GTF2I',
#  'GTF2IRD2',
#  'GYG2',
#  'HAMP',
#  'HAND2-AS1',
#  'HAS1',
#  'HCK',
#  'HCN1',
#  'HDAC2-AS2',
#  'HDAC5',
#  'HDAC9',
#  'HDC',
#  'HEATR3',
#  'HECTD4',
#  'HECW2',
#  'HEG1',
#  'HELLS',
#  'HERC2',
#  'HERPUD1',
#  'HES4',
#  'HIF1A',
#  'HIF3A',
#  'HIGD1B',
#  'HIST1H2AC',
#  'HLA-A',
#  'HLA-B',
#  'HLA-C',
#  'HLA-DRA',
#  'HNRNPDL',
#  'HNRNPH1',
#  'HOOK2',
#  'HP',
#  'HPGD',
#  'HSPA12A',
#  'HSPA9',
#  'HSPB7',
#  'HSPH1',
#  'HTR4',
#  'HYAL2',
#  'ICAM2',
#  'ID1',
#  'ID2',
#  'ID3',
#  'IER2',
#  'IER3',
#  'IFI27',
#  'IFITM2',
#  'IFNAR1',
#  'IFNG-AS1',
#  'IGF1',
#  'IGF1R',
#  'IGFBP2',
#  'IGFBP7',
#  'IGKC',
#  'IGSF21',
#  'IKBKB',
#  'IKZF1',
#  'IL16',
#  'IL18R1',
#  'IL1R1',
#  'IL1RAPL1',
#  'IL1RAPL2',
#  'IL7R',
#  'ILK',
#  'IMMT',
#  'INPP4A',
#  'INPP4B',
#  'INPP5D',
#  'INSR',
#  'IPO9-AS1',
#  'IQGAP2',
#  'IRAK3',
#  'ITGA1',
#  'ITGA7',
#  'ITGA8',
#  'ITGA9',
#  'ITGB1',
#  'ITGB8',
#  'ITIH5',
#  'ITK',
#  'ITLN1',
#  'ITPK1',
#  'ITPKB-AS1',
#  'ITPR2',
#  'ITSN1',
#  'ITSN2',
#  'IVD',
#  'JPH2',
#  'JUN',
#  'JUNB',
#  'JUP',
#  'KALRN',
#  'KANK1',
#  'KANK3',
#  'KANSL1L',
#  'KAZN',
#  'KCNAB1',
#  'KCNE1',
#  'KCNE4',
#  'KCNH5',
#  'KCNJ3',
#  'KCNJ8',
#  'KCNMA1',
#  'KCNMB2',
#  'KCNMB2-AS1',
#  'KCNMB4',
#  'KCNQ5',
#  'KCNT2',
#  'KDM5B',
#  'KIAA0232',
#  'KIAA0355',
#  'KIAA1217',
#  'KIAA1549',
#  'KIF13A',
#  'KIF18B',
#  'KIF20B',
#  'KIRREL3',
#  'KIT',
#  'KLF12',
#  'KLF13',
#  'KLF2',
#  'KLF6',
#  'KLHL29',
#  'KMT2A',
#  'KMT2E',
#  'KNTC1',
#  'KRT18',
#  'KRT19',
#  'L3MBTL4',
#  'LAMA2',
#  'LAMA3',
#  'LBH',
#  'LCP2',
#  'LDB2',
#  'LDB3',
#  'LDLRAD3',
#  'LEMD3',
#  'LGI4',
#  'LGMN',
#  'LGR6',
#  'LHFPL2',
#  'LIAS',
#  'LIMA1',
#  'LIMCH1',
#  'LIMS1',
#  'LINC00486',
#  'LINC00598',
#  'LINC00882',
#  'LINC01088',
#  'LINC01091',
#  'LINC01099',
#  'LINC01411',
#  'LINC01568',
#  'LINC01572',
#  'LINC01592',
#  'LINC01828',
#  'LINC02147',
#  'LINC02208',
#  'LINC02240',
#  'LINC02248',
#  'LINC02253',
#  'LINC02388',
#  'LINC02511',
#  'LINGO1',
#  'LIPE',
#  'LIPE-AS1',
#  'LMCD1',
#  'LMO7',
#  'LMOD1',
#  'LMOD2',
#  'LOXL2',
#  'LPAR1',
#  'LPAR6',
#  'LPIN1',
#  'LPL',
#  'LRIG1',
#  'LRMDA',
#  'LRP1',
#  'LRP1B',
#  'LRP2',
#  'LRRTM3',
#  'LRRTM4',
#  'LSAMP',
#  'LSM14A',
#  'LST1',
#  'LTBP1',
#  'LTBP4',
#  'LYN',
#  'LYST',
#  'LZTS1-AS1',
#  'MACROD2',
#  'MAGI1',
#  'MAGI2',
#  'MAGT1',
#  'MAML3',
#  'MAP3K11',
#  'MAP4',
#  'MAPK10',
#  'MAPK4',
#  'MARC1',
#  'MARCH1',
#  'MARCH3',
#  'MARK3',
#  'MAST4',
#  'MBD5',
#  'MBNL1',
#  'MCM7',
#  'MCTP1',
#  'MCTP2',
#  'MDFIC',
#  'ME1',
#  'MECOM',
#  'MED13L',
#  'MEF2C',
#  'MEG3',
#  'MEG8',
#  'MEIS2',
#  'MELK',
#  'MEST',
#  'MFGE8',
#  'MGAT5',
#  'MGP',
#  'MGST1',
#  'MGST2',
#  'MGST3',
#  'MICALL2',
#  'MIPEP',
#  'MIR193BHG',
#  'MIR22HG',
#  'MIR29B2CHG',
#  'MIR4435-2HG',
#  'MIR99AHG',
#  'MITF',
#  'MLIP',
#  'MLLT10',
#  'MLLT6',
#  'MLXIPL',
#  'MME',
#  'MMP16',
#  'MMRN1',
#  'MMS22L',
#  'MPZ',
#  'MRC1',
#  'MRC2',
#  'MS4A6A',
#  'MSC-AS1',
#  'MSR1',
#  'MT1E',
#  'MT2A',
#  'MTHFD1L',
#  'MTHFD2',
#  'MTUS1',
#  'MX2',
#  'MYBL1',
#  'MYBPC3',
#  'MYCBP2',
#  'MYH10',
#  'MYH11',
#  'MYH13',
#  'MYH6',
#  'MYH7',
#  'MYH7B',
#  'MYL2',
#  'MYL3',
#  'MYL4',
#  'MYL6',
#  'MYL7',
#  'MYO18B',
#  'MYO1F',
#  'MYOCD',
#  'MYOM2',
#  'MYPN',
#  'MYRIP',
#  'MYSM1',
#  'N4BP2L2',
#  'NAA35',
#  'NAIP',
#  'NAMPT',
#  'NAV1',
#  'NAV2',
#  'NCAM1',
#  'NCAM2',
#  'NDRG4',
#  'NDUFA4L2',
#  'NDUFAF8',
#  'NEAT1',
#  'NEB',
#  'NEBL',
#  'NEDD4L',
#  'NEGR1',
#  'NEXN',
#  'NFATC2',
#  'NFATC2IP',
#  'NFIB',
#  'NFKB1',
#  'NFKBIA',
#  'NFKBIZ',
#  'NFRKB',
#  'NGF',
#  'NHS',
#  'NHSL1',
#  'NID1',
#  'NIPBL',
#  'NKAIN2',
#  'NKAIN3',
#  'NKTR',
#  'NLGN1',
#  'NLGN4X',
#  'NLK',
#  'NLRC5',
#  'NNMT',
#  'NOL10',
#  'NOSTRIN',
#  'NOVA1',
#  'NPPA',
#  'NR2F1',
#  'NR4A1',
#  'NR4A3',
#  'NREP',
#  'NRG2',
#  'NRG3',
#  'NRXN1',
#  'NRXN3',
#  'NSD3',
#  'NSMCE2',
#  'NTM',
#  'NTN1',
#  'NTRK3',
#  'NUP210',
#  'NUP210L',
#  'NUP50-DT',
#  'NUPR1',
#  'NUSAP1',
#  'NXN',
#  'OBSCN',
#  'ODF2L',
#  'OGA',
#  'OGFRL1',
#  'OLFM2',
#  'OPCML',
#  'ORC2',
#  'OSBPL10',
#  'OSMR',
#  'OTUB1',
#  'P2RY8',
#  'PABPC4',
#  'PACS1',
#  'PAIP1',
#  'PALLD',
#  'PALM2-AKAP2',
#  'PALMD',
#  'PAM',
#  'PAPPA',
#  'PARD3B',
#  'PARP14',
#  'PARP4',
#  'PARP8',
#  'PATJ',
#  'PATL1',
#  'PBX1',
#  'PBX3',
#  'PC',
#  'PCDH15',
#  'PCDH7',
#  'PCDH9',
#  'PCED1A',
#  'PCED1B',
#  'PCSK7',
#  'PDCD6IP',
#  'PDE10A',
#  'PDE1C',
#  'PDE3B',
#  'PDE4B',
#  'PDE4D',
#  'PDE5A',
#  'PDE7A',
#  'PDE7B',
#  'PDGFD',
#  'PDGFRB',
#  'PDK4',
#  'PDLIM3',
#  'PDLIM7',
#  'PDXDC1',
#  'PDZRN4',
#  'PECAM1',
#  'PER1',
#  'PER3',
#  'PFKFB3',
#  'PGAP1',
#  'PGK1',
#  'PGM1',
#  'PHACTR1',
#  'PHACTR2',
#  'PHLDB1',
#  'PHLDB2',
#  'PIAS2',
#  'PID1',
#  'PIGX',
#  'PIK3R1',
#  'PIK3R5',
#  'PIP4K2A',
#  'PIP5K1B',
#  'PIR',
#  'PITPNC1',
#  'PITPNM2',
#  'PKHD1L1',
#  'PKIA',
#  'PKN2-AS1',
#  'PKN3',
#  'PLA2G2A',
#  'PLCB1',
#  'PLCB2',
#  'PLCE1',
#  'PLCG2',
#  'PLEKHA5',
#  'PLEKHG1',
#  'PLIN1',
#  'PLIN4',
#  'PLIN5',
#  'PLN',
#  'PLOD2',
#  'PLPP1',
#  'PLSCR1',
#  'PLVAP',
#  'PLXDC2',
#  'PLXNA4',
#  'PMP22',
#  'PNISR',
#  'PNPLA2',
#  'PODXL',
#  'POLQ',
#  'POPDC2',
#  'POSTN',
#  'POU6F2',
#  'PPARG',
#  'PPP1R12A',
#  'PPP1R13B',
#  'PPP1R16B',
#  'PPP1R17',
#  'PPP1R42',
#  'PPP2R2B',
#  'PPP2R5C',
#  'PPP3CA',
#  'PRDM16',
#  'PRELP',
#  'PRG4',
#  'PRICKLE1',
#  'PRIM2',
#  'PRIMA1',
#  'PRKAR2A',
#  'PRKAR2B',
#  'PRKCA',
#  'PRKCA-AS1',
#  'PRKCE',
#  ...]

# %%
SC = SC[:,use_genes] # filter SC

# %% [markdown]
# We need to scale again after removing unwanted genes, in order to again, have profiles of equal counts!

# %%
sc.pp.normalize_total(SC, target_sum=1)
# Out:
# /home/jel/.local/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
SC # the profiles are now much smaller which will reduce memory and speed up traininig time
# Out:
# AnnData object with n_obs × n_vars = 163959 × 1388
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45'
#     uns: 'cell_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ### Define and construct our 10-folds

# %%
# requires scikit learn
from sklearn.model_selection import StratifiedKFold

Y = SC.obs['cell_type']
X = SC.X

skf = StratifiedKFold(n_splits=10)
skf.get_n_splits(X, Y)
skf
# Out:
# StratifiedKFold(n_splits=10, random_state=None, shuffle=False)

# %%
from collections import Counter

i = 1
folds = []
for train_index, test_index in skf.split(X, Y):
    print("TRAIN:", train_index, "TEST:", test_index)
    # define our fold
    SC_fold_train = SC[train_index,]
    SC_fold_test = SC[test_index,]

    # do an additional fold for a validation set
    Y_fold = SC_fold_test.obs['cell_type']
    X_fold = SC_fold_test.X

    print(X_fold.shape)
    skf_fold = StratifiedKFold(n_splits=2)
    skf_fold.get_n_splits(X_fold, Y_fold)
    for test_index_2, val_index in skf_fold.split(X_fold, Y_fold):
        print("TEST (2):", test_index_2, "VAL:", val_index)
        SC_fold_val = SC_fold_test[val_index,]
        SC_fold_test = SC_fold_test[test_index_2,]
        break # break because we already have our 2 "folds" here
        
    folds.append([SC_fold_train, SC_fold_val, SC_fold_test])
    # verify that cell types are indeed stratified
    print(Counter(SC_fold_train.obs['cell_type']))
    print(Counter(SC_fold_test.obs['cell_type']))
    print(Counter(SC_fold_val.obs['cell_type']))
# Out:
# TRAIN: [ 13876  13879  13880 ... 163956 163957 163958] TEST: [    0     1     2 ... 39310 39317 39319]
# (16396, 1388)
# TEST (2): [ 5898  5900  5902 ... 16393 16394 16395] VAL: [    0     1     2 ... 15894 15899 15910]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33543, 'Fibroblast': 13899, 'Endothelial': 11495, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6742, 'Myeloid': 5030, 'Lymphoid': 4268, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 238, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [13876 13879 13880 ... 53673 53678 53718]
# (16396, 1388)
# TEST (2): [ 4086  4092  4099 ... 16393 16394 16395] VAL: [    0     1     2 ... 15635 15636 15637]
# Counter({'Ventricular_Cardiomyocyte': 61614, 'Pericytes': 33542, 'Fibroblast': 13899, 'Endothelial': 11495, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6742, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3422, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [20979 20981 20983 ... 67542 67543 67551]
# (16396, 1388)
# TEST (2): [ 3452  3453  3454 ... 16393 16394 16395] VAL: [    0     1     2 ... 14972 14987 14988]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13899, 'Endothelial': 11495, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [40402 40418 40420 ... 80022 80037 80050]
# (16396, 1388)
# TEST (2): [  111   112   113 ... 16393 16394 16395] VAL: [    0     1     2 ... 16156 16157 16158]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13898, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 773, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [ 52047  52048  52050 ... 113474 113475 113479]
# (16396, 1388)
# TEST (2): [ 3464  3465  3466 ... 16393 16394 16395] VAL: [    0     1     2 ... 15867 15875 15883]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13898, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 773, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [ 65722  65727  65741 ... 114957 114958 114959]
# (16396, 1388)
# TEST (2): [  111   112   113 ... 16393 16394 16395] VAL: [    0     1     2 ... 15996 15997 15998]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13898, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 773, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [ 79501  79568  79605 ... 121511 121513 121516]
# (16396, 1388)
# TEST (2): [ 1249  1250  1261 ... 16393 16394 16395] VAL: [    0     1     2 ... 14567 14568 14569]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13899, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1990, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [ 93707  93741  93743 ... 139617 139628 139671]
# (16396, 1388)
# TEST (2): [  111   112   113 ... 16393 16394 16395] VAL: [    0     1     2 ... 12862 12867 12954]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13899, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4269, 'Adipocytes': 1990, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 280, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 163956 163957 163958] TEST: [107901 110277 110285 ... 150598 150602 150607]
# (16396, 1388)
# TEST (2): [  111   112   113 ... 16393 16394 16395] VAL: [    0     1     2 ... 12939 12940 12941]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13899, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5029, 'Lymphoid': 4268, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 280, 'Lymphoid': 238, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})
# TRAIN: [     0      1      2 ... 150598 150602 150607] TEST: [126324 126325 126354 ... 163956 163957 163958]
# (16395, 1388)
# TEST (2): [  305   306   307 ... 16392 16393 16394] VAL: [    0     1     2 ... 10842 10846 10847]
# Counter({'Ventricular_Cardiomyocyte': 61613, 'Pericytes': 33542, 'Fibroblast': 13899, 'Endothelial': 11496, 'Atrial_Cardiomyocyte': 7146, 'Smooth_muscle_cells': 6743, 'Myeloid': 5030, 'Lymphoid': 4268, 'Adipocytes': 1991, 'Neuronal': 1836})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1863, 'Fibroblast': 772, 'Endothelial': 638, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 375, 'Myeloid': 279, 'Lymphoid': 238, 'Adipocytes': 110, 'Neuronal': 102})
# Counter({'Ventricular_Cardiomyocyte': 3423, 'Pericytes': 1864, 'Fibroblast': 772, 'Endothelial': 639, 'Atrial_Cardiomyocyte': 397, 'Smooth_muscle_cells': 374, 'Myeloid': 279, 'Lymphoid': 237, 'Adipocytes': 111, 'Neuronal': 102})

# %%
experiments = []
for i in range(len(folds)):
    exp_ = AS.DeconvolutionExperiment(SC)
    exp_.SC_train = folds[i][0] # train
    exp_.SC_val = folds[i][1]   # validation
    exp_.SC_test = folds[i][2]  # test
    exp_.setCellTypeColumn('cell_type')
    exp_.setVerbosity(True)

    experiments.append(exp_)



print(experiments) # our 10 folded experiments
# Out:
# [<antisplodge.DeconvolutionExperiment object at 0x7f651b18ce20>, <antisplodge.DeconvolutionExperiment object at 0x7f651b00e800>, <antisplodge.DeconvolutionExperiment object at 0x7f651af729b0>, <antisplodge.DeconvolutionExperiment object at 0x7f651af72b30>, <antisplodge.DeconvolutionExperiment object at 0x7f651af72c50>, <antisplodge.DeconvolutionExperiment object at 0x7f651af738e0>, <antisplodge.DeconvolutionExperiment object at 0x7f6641382ec0>, <antisplodge.DeconvolutionExperiment object at 0x7f651af71090>, <antisplodge.DeconvolutionExperiment object at 0x7f6641381ae0>, <antisplodge.DeconvolutionExperiment object at 0x7f651af73970>]

# %% [markdown]
# Then we generate 100.000 training, 2.500 validation, and, 2.500 test samples.
# And load these into data loaders for use in training of the neural network.
#
# Notice: This might require more RAM than the average laptop have.

# %%
for exp_ in experiments:
    exp_.generateTrainTestValidation(num_profiles=[100000,2500,2500], CD=[10,10])
    # Load the profiles into data loaders
    exp_.setupDataLoaders(batch_size=500)
# Out:
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)
# GENERATING PROFILES
# GENERATING TRAIN DATASET (N=100000)
# GENERATING VALIDATION DATASET (N=2500)
# GENERATING TEST DATASET (N=2500)

# %% [markdown]
# We then define the model (with default values) and use the first cuda device (cuda_id=1).

# %%
# Initialize Neural network-model and allocate it to the cuda_id specified
# Use 'cuda_id="cpu"' if you want to allocate it to a cpu
for exp_ in experiments:
    exp_.setupModel(cuda_id=0)
# Out:
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0
# (CUDA) device is: cuda:0

# %% [markdown]
# We then train the network with 25 warm restarts, this means whenever we finish a training session we load the best model settings we have found so far back onto the model and continue from there in the next setting.

# %%
for i, exp_ in enumerate(experiments):
    # do 25 warm restarts with decreasing learning rate
    lr = 0.001 
    best_error=None # no target error to beat in the beginning
    for k in range(25):
        
        # Consider changing learning rate (lr) during run more dynamically
        if k >= 5:
            lr = 0.0005
        if k >= 10:
            lr = 0.0001
        if k >= 15:
            lr = 0.00005
        exp_.setupOptimizerAndCriterion(learning_rate = lr)
        # Train the experiment constructed by passing the experiment to the AntiSplodge training function 
        AS.train(exp_, save_file=f"ModelCheckpoint_{i}.pt", patience=5, best_loss=best_error) # For longer training, increase patience threshold
        best_error = AS.getMeanJSD(exp_, "validation") # set best error as the target error to beat
        
        print("Exp [{}] - Restart [{}] - JSDs".format(i, k),AS.getMeanJSD(exp_, "train"), AS.getMeanJSD(exp_, "validation"))
# Out:
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.02472 | (Valid): 0.01993 - (mean)JSD: (Train) 0.11659 | (Valid) 0.12424
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01852 | (Valid): 0.01915 - (mean)JSD: (Train) 0.10339 | (Valid) 0.11411
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.01720 | (Valid): 0.01963 - (mean)JSD: (Train) 0.11191 | (Valid) 0.12282
#
# Epoch: 004 | Epochs since last increase: 002
# Loss: (Train) 0.01658 | (Valid): 0.01808 - (mean)JSD: (Train) 0.10451 | (Valid) 0.11528
#
# Epoch: 005 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01616 | (Valid): 0.01741 - (mean)JSD: (Train) 0.09971 | (Valid) 0.11226
#
# Epoch: 006 | Epochs since last increase: 001
# Loss: (Train) 0.01531 | (Valid): 0.01698 - (mean)JSD: (Train) 0.10346 | (Valid) 0.11455
#
# Epoch: 007 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01504 | (Valid): 0.01674 - (mean)JSD: (Train) 0.09401 | (Valid) 0.10574
#
# Epoch: 008 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01487 | (Valid): 0.01506 - (mean)JSD: (Train) 0.09096 | (Valid) 0.09833
#
# Epoch: 009 | Epochs since last increase: 001
# Loss: (Train) 0.01453 | (Valid): 0.01668 - (mean)JSD: (Train) 0.09126 | (Valid) 0.10528
#
# Epoch: 010 | Epochs since last increase: 002
# Loss: (Train) 0.01437 | (Valid): 0.01560 - (mean)JSD: (Train) 0.08322 | (Valid) 0.09841
#
# Epoch: 011 | Epochs since last increase: 003
# Loss: (Train) 0.01421 | (Valid): 0.01566 - (mean)JSD: (Train) 0.08608 | (Valid) 0.09949
#
# Epoch: 012 | Epochs since last increase: 004
# Loss: (Train) 0.01403 | (Valid): 0.01573 - (mean)JSD: (Train) 0.08552 | (Valid) 0.10229
#
# Epoch: 013 | Epochs since last increase: 005
# Loss: (Train) 0.01387 | (Valid): 0.01717 - (mean)JSD: (Train) 0.08741 | (Valid) 0.10400
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 50.57 (0.84 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [0] - JSDs 0.0909622591982862 0.09832907503477369
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01527 | (Valid): 0.01615 - (mean)JSD: (Train) 0.09277 | (Valid) 0.10841
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01492 | (Valid): 0.01668 - (mean)JSD: (Train) 0.09489 | (Valid) 0.10552
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01438 | (Valid): 0.01600 - (mean)JSD: (Train) 0.08960 | (Valid) 0.10691
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01420 | (Valid): 0.01545 - (mean)JSD: (Train) 0.08905 | (Valid) 0.10333
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01403 | (Valid): 0.01454 - (mean)JSD: (Train) 0.08676 | (Valid) 0.09968
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01378 | (Valid): 0.01559 - (mean)JSD: (Train) 0.08954 | (Valid) 0.10169
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 24.16 (0.40 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [1] - JSDs 0.0909622591982862 0.09832907503477369
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01540 | (Valid): 0.01577 - (mean)JSD: (Train) 0.09150 | (Valid) 0.10279
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01471 | (Valid): 0.01593 - (mean)JSD: (Train) 0.09055 | (Valid) 0.10297
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01457 | (Valid): 0.01614 - (mean)JSD: (Train) 0.08664 | (Valid) 0.10295
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01433 | (Valid): 0.01551 - (mean)JSD: (Train) 0.08785 | (Valid) 0.09863
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01411 | (Valid): 0.01589 - (mean)JSD: (Train) 0.08708 | (Valid) 0.10094
#
# Epoch: 006 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01387 | (Valid): 0.01540 - (mean)JSD: (Train) 0.08553 | (Valid) 0.09578
#
# Epoch: 007 | Epochs since last increase: 001
# Loss: (Train) 0.01364 | (Valid): 0.01530 - (mean)JSD: (Train) 0.08711 | (Valid) 0.10103
#
# Epoch: 008 | Epochs since last increase: 002
# Loss: (Train) 0.01358 | (Valid): 0.01494 - (mean)JSD: (Train) 0.08109 | (Valid) 0.09738
#
# Epoch: 009 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01328 | (Valid): 0.01422 - (mean)JSD: (Train) 0.07973 | (Valid) 0.09244
#
# Epoch: 010 | Epochs since last increase: 001
# Loss: (Train) 0.01315 | (Valid): 0.01496 - (mean)JSD: (Train) 0.08239 | (Valid) 0.09750
#
# Epoch: 011 | Epochs since last increase: 002
# Loss: (Train) 0.01294 | (Valid): 0.01517 - (mean)JSD: (Train) 0.08329 | (Valid) 0.09888
#
# Epoch: 012 | Epochs since last increase: 003
# Loss: (Train) 0.01290 | (Valid): 0.01489 - (mean)JSD: (Train) 0.07864 | (Valid) 0.09696
#
# Epoch: 013 | Epochs since last increase: 004
# Loss: (Train) 0.01280 | (Valid): 0.01503 - (mean)JSD: (Train) 0.07408 | (Valid) 0.09403
#
# Epoch: 014 | Epochs since last increase: 005
# Loss: (Train) 0.01252 | (Valid): 0.01457 - (mean)JSD: (Train) 0.07831 | (Valid) 0.09507
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 54.94 (0.92 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [2] - JSDs 0.07972745987694757 0.09244070241934675
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01345 | (Valid): 0.01573 - (mean)JSD: (Train) 0.08297 | (Valid) 0.09862
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01311 | (Valid): 0.01565 - (mean)JSD: (Train) 0.07782 | (Valid) 0.09636
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01305 | (Valid): 0.01514 - (mean)JSD: (Train) 0.08126 | (Valid) 0.09614
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01274 | (Valid): 0.01486 - (mean)JSD: (Train) 0.07882 | (Valid) 0.09619
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01275 | (Valid): 0.01474 - (mean)JSD: (Train) 0.07734 | (Valid) 0.09574
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01257 | (Valid): 0.01460 - (mean)JSD: (Train) 0.07965 | (Valid) 0.09705
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.45 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [3] - JSDs 0.07972745987694757 0.09244070241934675
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01358 | (Valid): 0.01579 - (mean)JSD: (Train) 0.08417 | (Valid) 0.09807
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01316 | (Valid): 0.01474 - (mean)JSD: (Train) 0.08029 | (Valid) 0.09730
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01299 | (Valid): 0.01437 - (mean)JSD: (Train) 0.07612 | (Valid) 0.09261
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01290 | (Valid): 0.01468 - (mean)JSD: (Train) 0.08201 | (Valid) 0.09640
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01278 | (Valid): 0.01530 - (mean)JSD: (Train) 0.08026 | (Valid) 0.09851
#
# Epoch: 006 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01258 | (Valid): 0.01390 - (mean)JSD: (Train) 0.07399 | (Valid) 0.09163
#
# Epoch: 007 | Epochs since last increase: 001
# Loss: (Train) 0.01230 | (Valid): 0.01511 - (mean)JSD: (Train) 0.08072 | (Valid) 0.09744
#
# Epoch: 008 | Epochs since last increase: 002
# Loss: (Train) 0.01216 | (Valid): 0.01471 - (mean)JSD: (Train) 0.07718 | (Valid) 0.09414
#
# Epoch: 009 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01208 | (Valid): 0.01411 - (mean)JSD: (Train) 0.07197 | (Valid) 0.08939
#
# Epoch: 010 | Epochs since last increase: 001
# Loss: (Train) 0.01218 | (Valid): 0.01446 - (mean)JSD: (Train) 0.07762 | (Valid) 0.09772
#
# Epoch: 011 | Epochs since last increase: 002
# Loss: (Train) 0.01179 | (Valid): 0.01500 - (mean)JSD: (Train) 0.07591 | (Valid) 0.09544
#
# Epoch: 012 | Epochs since last increase: 003
# Loss: (Train) 0.01165 | (Valid): 0.01490 - (mean)JSD: (Train) 0.07698 | (Valid) 0.09649
#
# Epoch: 013 | Epochs since last increase: 004
# Loss: (Train) 0.01164 | (Valid): 0.01467 - (mean)JSD: (Train) 0.07553 | (Valid) 0.09661
#
# Epoch: 014 | Epochs since last increase: 005
# Loss: (Train) 0.01151 | (Valid): 0.01379 - (mean)JSD: (Train) 0.07075 | (Valid) 0.09167
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 54.47 (0.91 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [4] - JSDs 0.07197037160544656 0.08938525942070905
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01130 | (Valid): 0.01365 - (mean)JSD: (Train) 0.06841 | (Valid) 0.09019
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01121 | (Valid): 0.01373 - (mean)JSD: (Train) 0.06933 | (Valid) 0.08968
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01095 | (Valid): 0.01357 - (mean)JSD: (Train) 0.06766 | (Valid) 0.08991
#
# Epoch: 004 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01082 | (Valid): 0.01362 - (mean)JSD: (Train) 0.06486 | (Valid) 0.08908
#
# Epoch: 005 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01078 | (Valid): 0.01359 - (mean)JSD: (Train) 0.06622 | (Valid) 0.08807
#
# Epoch: 006 | Epochs since last increase: 001
# Loss: (Train) 0.01070 | (Valid): 0.01359 - (mean)JSD: (Train) 0.06520 | (Valid) 0.08997
#
# Epoch: 007 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01062 | (Valid): 0.01321 - (mean)JSD: (Train) 0.06533 | (Valid) 0.08787
#
# Epoch: 008 | Epochs since last increase: 001
# Loss: (Train) 0.01058 | (Valid): 0.01329 - (mean)JSD: (Train) 0.06588 | (Valid) 0.08831
#
# Epoch: 009 | Epochs since last increase: 002
# Loss: (Train) 0.01048 | (Valid): 0.01342 - (mean)JSD: (Train) 0.06530 | (Valid) 0.08852
#
# Epoch: 010 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01047 | (Valid): 0.01302 - (mean)JSD: (Train) 0.06446 | (Valid) 0.08646
#
# Epoch: 011 | Epochs since last increase: 001
# Loss: (Train) 0.01030 | (Valid): 0.01363 - (mean)JSD: (Train) 0.06672 | (Valid) 0.09090
#
# Epoch: 012 | Epochs since last increase: 002
# Loss: (Train) 0.01027 | (Valid): 0.01393 - (mean)JSD: (Train) 0.06382 | (Valid) 0.08996
#
# Epoch: 013 | Epochs since last increase: 003
# Loss: (Train) 0.01017 | (Valid): 0.01271 - (mean)JSD: (Train) 0.06384 | (Valid) 0.08690
#
# Epoch: 014 | Epochs since last increase: 004
# Loss: (Train) 0.01016 | (Valid): 0.01359 - (mean)JSD: (Train) 0.06213 | (Valid) 0.08865
#
# Epoch: 015 | Epochs since last increase: 005
# Loss: (Train) 0.01018 | (Valid): 0.01318 - (mean)JSD: (Train) 0.06503 | (Valid) 0.08787
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 58.40 (0.97 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [5] - JSDs 0.06445815217641569 0.08645994463754217
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01039 | (Valid): 0.01355 - (mean)JSD: (Train) 0.06536 | (Valid) 0.08882
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01031 | (Valid): 0.01335 - (mean)JSD: (Train) 0.06234 | (Valid) 0.08879
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01027 | (Valid): 0.01340 - (mean)JSD: (Train) 0.06470 | (Valid) 0.08957
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01019 | (Valid): 0.01331 - (mean)JSD: (Train) 0.06553 | (Valid) 0.08916
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01011 | (Valid): 0.01332 - (mean)JSD: (Train) 0.06294 | (Valid) 0.08912
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01004 | (Valid): 0.01298 - (mean)JSD: (Train) 0.06292 | (Valid) 0.08886
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.49 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [6] - JSDs 0.06445815217641569 0.08645994463754217
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01041 | (Valid): 0.01330 - (mean)JSD: (Train) 0.06404 | (Valid) 0.08824
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01028 | (Valid): 0.01333 - (mean)JSD: (Train) 0.06733 | (Valid) 0.09076
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01024 | (Valid): 0.01337 - (mean)JSD: (Train) 0.06467 | (Valid) 0.09046
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01026 | (Valid): 0.01382 - (mean)JSD: (Train) 0.06712 | (Valid) 0.09263
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01016 | (Valid): 0.01311 - (mean)JSD: (Train) 0.06376 | (Valid) 0.08863
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01005 | (Valid): 0.01357 - (mean)JSD: (Train) 0.06112 | (Valid) 0.08833
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.40 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [7] - JSDs 0.06445815217641569 0.08645994463754217
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01040 | (Valid): 0.01325 - (mean)JSD: (Train) 0.06546 | (Valid) 0.09042
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01030 | (Valid): 0.01353 - (mean)JSD: (Train) 0.06235 | (Valid) 0.08737
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01021 | (Valid): 0.01334 - (mean)JSD: (Train) 0.06355 | (Valid) 0.08901
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01011 | (Valid): 0.01346 - (mean)JSD: (Train) 0.06349 | (Valid) 0.09115
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01012 | (Valid): 0.01348 - (mean)JSD: (Train) 0.06474 | (Valid) 0.09142
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01017 | (Valid): 0.01294 - (mean)JSD: (Train) 0.06231 | (Valid) 0.08712
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.33 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [8] - JSDs 0.06445815217641569 0.08645994463754217
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01044 | (Valid): 0.01328 - (mean)JSD: (Train) 0.06480 | (Valid) 0.08844
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01028 | (Valid): 0.01317 - (mean)JSD: (Train) 0.06510 | (Valid) 0.08964
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01022 | (Valid): 0.01358 - (mean)JSD: (Train) 0.06336 | (Valid) 0.08777
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01015 | (Valid): 0.01380 - (mean)JSD: (Train) 0.06636 | (Valid) 0.09326
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01014 | (Valid): 0.01347 - (mean)JSD: (Train) 0.06288 | (Valid) 0.08975
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00995 | (Valid): 0.01310 - (mean)JSD: (Train) 0.06541 | (Valid) 0.08829
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.40 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [9] - JSDs 0.06445815217641569 0.08645994463754217
# Epoch: 001 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.00967 | (Valid): 0.01256 - (mean)JSD: (Train) 0.05879 | (Valid) 0.08518
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.00951 | (Valid): 0.01263 - (mean)JSD: (Train) 0.05792 | (Valid) 0.08430
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.00947 | (Valid): 0.01273 - (mean)JSD: (Train) 0.05883 | (Valid) 0.08635
#
# Epoch: 004 | Epochs since last increase: 002
# Loss: (Train) 0.00944 | (Valid): 0.01253 - (mean)JSD: (Train) 0.05778 | (Valid) 0.08502
#
# Epoch: 005 | Epochs since last increase: 003
# Loss: (Train) 0.00939 | (Valid): 0.01267 - (mean)JSD: (Train) 0.05876 | (Valid) 0.08595
#
# Epoch: 006 | Epochs since last increase: 004
# Loss: (Train) 0.00943 | (Valid): 0.01273 - (mean)JSD: (Train) 0.05730 | (Valid) 0.08601
#
# Epoch: 007 | Epochs since last increase: 005
# Loss: (Train) 0.00935 | (Valid): 0.01288 - (mean)JSD: (Train) 0.05804 | (Valid) 0.08696
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 27.38 (0.46 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [10] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00947 | (Valid): 0.01261 - (mean)JSD: (Train) 0.05734 | (Valid) 0.08516
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00941 | (Valid): 0.01273 - (mean)JSD: (Train) 0.05761 | (Valid) 0.08619
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00940 | (Valid): 0.01252 - (mean)JSD: (Train) 0.05781 | (Valid) 0.08564
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00939 | (Valid): 0.01272 - (mean)JSD: (Train) 0.05826 | (Valid) 0.08648
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00935 | (Valid): 0.01268 - (mean)JSD: (Train) 0.05762 | (Valid) 0.08607
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00932 | (Valid): 0.01267 - (mean)JSD: (Train) 0.05719 | (Valid) 0.08578
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.29 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [11] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00944 | (Valid): 0.01270 - (mean)JSD: (Train) 0.05900 | (Valid) 0.08697
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00945 | (Valid): 0.01272 - (mean)JSD: (Train) 0.05737 | (Valid) 0.08478
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00938 | (Valid): 0.01253 - (mean)JSD: (Train) 0.05717 | (Valid) 0.08516
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00937 | (Valid): 0.01276 - (mean)JSD: (Train) 0.05767 | (Valid) 0.08605
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00935 | (Valid): 0.01282 - (mean)JSD: (Train) 0.05790 | (Valid) 0.08627
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00933 | (Valid): 0.01260 - (mean)JSD: (Train) 0.05675 | (Valid) 0.08493
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.48 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [12] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00950 | (Valid): 0.01271 - (mean)JSD: (Train) 0.05791 | (Valid) 0.08567
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00945 | (Valid): 0.01278 - (mean)JSD: (Train) 0.05760 | (Valid) 0.08548
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00942 | (Valid): 0.01270 - (mean)JSD: (Train) 0.05728 | (Valid) 0.08532
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00941 | (Valid): 0.01266 - (mean)JSD: (Train) 0.05763 | (Valid) 0.08612
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00935 | (Valid): 0.01270 - (mean)JSD: (Train) 0.05748 | (Valid) 0.08624
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00931 | (Valid): 0.01255 - (mean)JSD: (Train) 0.05742 | (Valid) 0.08502
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.37 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [13] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00953 | (Valid): 0.01268 - (mean)JSD: (Train) 0.05727 | (Valid) 0.08459
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00944 | (Valid): 0.01271 - (mean)JSD: (Train) 0.05783 | (Valid) 0.08651
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00941 | (Valid): 0.01266 - (mean)JSD: (Train) 0.05791 | (Valid) 0.08582
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00939 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05783 | (Valid) 0.08590
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00935 | (Valid): 0.01260 - (mean)JSD: (Train) 0.05768 | (Valid) 0.08541
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00930 | (Valid): 0.01255 - (mean)JSD: (Train) 0.05913 | (Valid) 0.08636
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.40 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [14] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00935 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05736 | (Valid) 0.08524
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00935 | (Valid): 0.01253 - (mean)JSD: (Train) 0.05775 | (Valid) 0.08482
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00932 | (Valid): 0.01247 - (mean)JSD: (Train) 0.05738 | (Valid) 0.08447
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00927 | (Valid): 0.01263 - (mean)JSD: (Train) 0.05718 | (Valid) 0.08506
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00929 | (Valid): 0.01266 - (mean)JSD: (Train) 0.05674 | (Valid) 0.08565
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00927 | (Valid): 0.01269 - (mean)JSD: (Train) 0.05694 | (Valid) 0.08577
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.28 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [15] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00936 | (Valid): 0.01270 - (mean)JSD: (Train) 0.05841 | (Valid) 0.08671
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00932 | (Valid): 0.01276 - (mean)JSD: (Train) 0.05884 | (Valid) 0.08735
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00933 | (Valid): 0.01260 - (mean)JSD: (Train) 0.05768 | (Valid) 0.08564
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00928 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05695 | (Valid) 0.08452
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00928 | (Valid): 0.01270 - (mean)JSD: (Train) 0.05692 | (Valid) 0.08546
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00924 | (Valid): 0.01253 - (mean)JSD: (Train) 0.05760 | (Valid) 0.08486
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.45 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [16] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00935 | (Valid): 0.01253 - (mean)JSD: (Train) 0.05767 | (Valid) 0.08519
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00935 | (Valid): 0.01263 - (mean)JSD: (Train) 0.05759 | (Valid) 0.08520
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00932 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05753 | (Valid) 0.08511
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00930 | (Valid): 0.01255 - (mean)JSD: (Train) 0.05705 | (Valid) 0.08516
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00928 | (Valid): 0.01256 - (mean)JSD: (Train) 0.05747 | (Valid) 0.08566
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00929 | (Valid): 0.01256 - (mean)JSD: (Train) 0.05715 | (Valid) 0.08497
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.32 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [17] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00939 | (Valid): 0.01259 - (mean)JSD: (Train) 0.05753 | (Valid) 0.08468
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00932 | (Valid): 0.01267 - (mean)JSD: (Train) 0.05747 | (Valid) 0.08546
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00929 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05666 | (Valid) 0.08496
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00929 | (Valid): 0.01264 - (mean)JSD: (Train) 0.05731 | (Valid) 0.08542
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00933 | (Valid): 0.01264 - (mean)JSD: (Train) 0.05800 | (Valid) 0.08633
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00927 | (Valid): 0.01272 - (mean)JSD: (Train) 0.05692 | (Valid) 0.08569
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.48 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [18] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00937 | (Valid): 0.01268 - (mean)JSD: (Train) 0.05839 | (Valid) 0.08610
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00935 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05786 | (Valid) 0.08572
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00930 | (Valid): 0.01263 - (mean)JSD: (Train) 0.05785 | (Valid) 0.08578
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00930 | (Valid): 0.01260 - (mean)JSD: (Train) 0.05737 | (Valid) 0.08525
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00929 | (Valid): 0.01265 - (mean)JSD: (Train) 0.05817 | (Valid) 0.08677
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00925 | (Valid): 0.01261 - (mean)JSD: (Train) 0.05683 | (Valid) 0.08519
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.33 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [19] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00937 | (Valid): 0.01255 - (mean)JSD: (Train) 0.05744 | (Valid) 0.08485
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00933 | (Valid): 0.01267 - (mean)JSD: (Train) 0.05787 | (Valid) 0.08524
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00935 | (Valid): 0.01257 - (mean)JSD: (Train) 0.05842 | (Valid) 0.08620
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00932 | (Valid): 0.01261 - (mean)JSD: (Train) 0.05651 | (Valid) 0.08482
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00929 | (Valid): 0.01267 - (mean)JSD: (Train) 0.05728 | (Valid) 0.08516
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00927 | (Valid): 0.01259 - (mean)JSD: (Train) 0.05769 | (Valid) 0.08534
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.48 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [20] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00937 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05848 | (Valid) 0.08635
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00933 | (Valid): 0.01265 - (mean)JSD: (Train) 0.05759 | (Valid) 0.08527
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00930 | (Valid): 0.01266 - (mean)JSD: (Train) 0.05739 | (Valid) 0.08618
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00930 | (Valid): 0.01257 - (mean)JSD: (Train) 0.05739 | (Valid) 0.08550
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00932 | (Valid): 0.01252 - (mean)JSD: (Train) 0.05721 | (Valid) 0.08488
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00928 | (Valid): 0.01261 - (mean)JSD: (Train) 0.05797 | (Valid) 0.08656
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.39 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [21] - JSDs 0.05792082261792887 0.084295868492973
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00937 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05720 | (Valid) 0.08465
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00934 | (Valid): 0.01257 - (mean)JSD: (Train) 0.05800 | (Valid) 0.08488
#
# Epoch: 003 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.00930 | (Valid): 0.01249 - (mean)JSD: (Train) 0.05719 | (Valid) 0.08425
#
# Epoch: 004 | Epochs since last increase: 001
# Loss: (Train) 0.00931 | (Valid): 0.01266 - (mean)JSD: (Train) 0.05763 | (Valid) 0.08553
#
# Epoch: 005 | Epochs since last increase: 002
# Loss: (Train) 0.00929 | (Valid): 0.01255 - (mean)JSD: (Train) 0.05742 | (Valid) 0.08498
#
# Epoch: 006 | Epochs since last increase: 003
# Loss: (Train) 0.00929 | (Valid): 0.01256 - (mean)JSD: (Train) 0.05714 | (Valid) 0.08463
#
# Epoch: 007 | Epochs since last increase: 004
# Loss: (Train) 0.00928 | (Valid): 0.01268 - (mean)JSD: (Train) 0.05783 | (Valid) 0.08659
#
# Epoch: 008 | Epochs since last increase: 005
# Loss: (Train) 0.00926 | (Valid): 0.01260 - (mean)JSD: (Train) 0.05702 | (Valid) 0.08456
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 31.59 (0.53 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [22] - JSDs 0.05719237242445511 0.08424919413975201
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00927 | (Valid): 0.01271 - (mean)JSD: (Train) 0.05764 | (Valid) 0.08620
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00929 | (Valid): 0.01264 - (mean)JSD: (Train) 0.05797 | (Valid) 0.08640
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00928 | (Valid): 0.01262 - (mean)JSD: (Train) 0.05692 | (Valid) 0.08542
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00927 | (Valid): 0.01261 - (mean)JSD: (Train) 0.05693 | (Valid) 0.08535
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00921 | (Valid): 0.01263 - (mean)JSD: (Train) 0.05717 | (Valid) 0.08555
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00923 | (Valid): 0.01259 - (mean)JSD: (Train) 0.05679 | (Valid) 0.08554
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.48 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [23] - JSDs 0.05719237242445511 0.08424919413975201
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00929 | (Valid): 0.01263 - (mean)JSD: (Train) 0.05680 | (Valid) 0.08517
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00930 | (Valid): 0.01253 - (mean)JSD: (Train) 0.05717 | (Valid) 0.08500
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00928 | (Valid): 0.01259 - (mean)JSD: (Train) 0.05681 | (Valid) 0.08513
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00929 | (Valid): 0.01265 - (mean)JSD: (Train) 0.05683 | (Valid) 0.08569
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00925 | (Valid): 0.01258 - (mean)JSD: (Train) 0.05777 | (Valid) 0.08602
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00924 | (Valid): 0.01252 - (mean)JSD: (Train) 0.05699 | (Valid) 0.08511
#
# Finished training (checkpoint saved in: ModelCheckpoint_0.pt)
# Time elapsed: 23.37 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_0.pt
# Exp [0] - Restart [24] - JSDs 0.05719237242445511 0.08424919413975201
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.02462 | (Valid): 0.02071 - (mean)JSD: (Train) 0.11922 | (Valid) 0.13414
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01842 | (Valid): 0.02105 - (mean)JSD: (Train) 0.12338 | (Valid) 0.14096
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01773 | (Valid): 0.01947 - (mean)JSD: (Train) 0.12001 | (Valid) 0.13612
#
# Epoch: 004 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01673 | (Valid): 0.01767 - (mean)JSD: (Train) 0.10495 | (Valid) 0.12133
#
# Epoch: 005 | Epochs since last increase: 001
# Loss: (Train) 0.01591 | (Valid): 0.01944 - (mean)JSD: (Train) 0.11258 | (Valid) 0.13452
#
# Epoch: 006 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01572 | (Valid): 0.01720 - (mean)JSD: (Train) 0.09547 | (Valid) 0.11293
#
# Epoch: 007 | Epochs since last increase: 001
# Loss: (Train) 0.01542 | (Valid): 0.01724 - (mean)JSD: (Train) 0.09791 | (Valid) 0.11487
#
# Epoch: 008 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01496 | (Valid): 0.01587 - (mean)JSD: (Train) 0.08639 | (Valid) 0.10483
#
# Epoch: 009 | Epochs since last increase: 001
# Loss: (Train) 0.01463 | (Valid): 0.01642 - (mean)JSD: (Train) 0.09083 | (Valid) 0.10843
#
# Epoch: 010 | Epochs since last increase: 002
# Loss: (Train) 0.01442 | (Valid): 0.01573 - (mean)JSD: (Train) 0.08765 | (Valid) 0.10491
#
# Epoch: 011 | Epochs since last increase: 003
# Loss: (Train) 0.01412 | (Valid): 0.01596 - (mean)JSD: (Train) 0.08923 | (Valid) 0.11036
#
# Epoch: 012 | Epochs since last increase: 004
# Loss: (Train) 0.01409 | (Valid): 0.01488 - (mean)JSD: (Train) 0.08769 | (Valid) 0.10522
#
# Epoch: 013 | Epochs since last increase: 005
# Loss: (Train) 0.01391 | (Valid): 0.01587 - (mean)JSD: (Train) 0.08735 | (Valid) 0.10909
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 50.43 (0.84 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [0] - JSDs 0.08639312594735293 0.10482854298766378
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01547 | (Valid): 0.01618 - (mean)JSD: (Train) 0.09378 | (Valid) 0.10607
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01481 | (Valid): 0.01532 - (mean)JSD: (Train) 0.08640 | (Valid) 0.09899
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.01454 | (Valid): 0.01618 - (mean)JSD: (Train) 0.08757 | (Valid) 0.10879
#
# Epoch: 004 | Epochs since last increase: 002
# Loss: (Train) 0.01415 | (Valid): 0.01662 - (mean)JSD: (Train) 0.09227 | (Valid) 0.11489
#
# Epoch: 005 | Epochs since last increase: 003
# Loss: (Train) 0.01388 | (Valid): 0.01579 - (mean)JSD: (Train) 0.08557 | (Valid) 0.10711
#
# Epoch: 006 | Epochs since last increase: 004
# Loss: (Train) 0.01364 | (Valid): 0.01532 - (mean)JSD: (Train) 0.08253 | (Valid) 0.10660
#
# Epoch: 007 | Epochs since last increase: 005
# Loss: (Train) 0.01349 | (Valid): 0.01462 - (mean)JSD: (Train) 0.08406 | (Valid) 0.10200
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 27.33 (0.46 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [1] - JSDs 0.08640338547148228 0.09898985411929218
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01485 | (Valid): 0.01605 - (mean)JSD: (Train) 0.09056 | (Valid) 0.10667
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01404 | (Valid): 0.01565 - (mean)JSD: (Train) 0.08934 | (Valid) 0.10501
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01398 | (Valid): 0.01521 - (mean)JSD: (Train) 0.08595 | (Valid) 0.10618
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01356 | (Valid): 0.01503 - (mean)JSD: (Train) 0.08460 | (Valid) 0.10501
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01352 | (Valid): 0.01455 - (mean)JSD: (Train) 0.08499 | (Valid) 0.10146
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01348 | (Valid): 0.01538 - (mean)JSD: (Train) 0.08156 | (Valid) 0.10353
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.27 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [2] - JSDs 0.08640338547148228 0.09898985411929218
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01468 | (Valid): 0.01594 - (mean)JSD: (Train) 0.08739 | (Valid) 0.10701
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01431 | (Valid): 0.01589 - (mean)JSD: (Train) 0.08951 | (Valid) 0.10687
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01399 | (Valid): 0.01597 - (mean)JSD: (Train) 0.08887 | (Valid) 0.10858
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01380 | (Valid): 0.01499 - (mean)JSD: (Train) 0.08328 | (Valid) 0.10625
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01357 | (Valid): 0.01461 - (mean)JSD: (Train) 0.08011 | (Valid) 0.10079
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01327 | (Valid): 0.01458 - (mean)JSD: (Train) 0.08403 | (Valid) 0.10219
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.33 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [3] - JSDs 0.08640338547148228 0.09898985411929218
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01482 | (Valid): 0.01612 - (mean)JSD: (Train) 0.09105 | (Valid) 0.10718
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01436 | (Valid): 0.01586 - (mean)JSD: (Train) 0.08623 | (Valid) 0.10827
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01401 | (Valid): 0.01540 - (mean)JSD: (Train) 0.08654 | (Valid) 0.10557
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01365 | (Valid): 0.01641 - (mean)JSD: (Train) 0.08994 | (Valid) 0.11089
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01348 | (Valid): 0.01555 - (mean)JSD: (Train) 0.08109 | (Valid) 0.10560
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01334 | (Valid): 0.01657 - (mean)JSD: (Train) 0.08742 | (Valid) 0.11407
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.37 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [4] - JSDs 0.08640338547148228 0.09898985411929218
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01361 | (Valid): 0.01444 - (mean)JSD: (Train) 0.07896 | (Valid) 0.09925
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01307 | (Valid): 0.01443 - (mean)JSD: (Train) 0.07844 | (Valid) 0.09812
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.01302 | (Valid): 0.01420 - (mean)JSD: (Train) 0.07830 | (Valid) 0.09946
#
# Epoch: 004 | Epochs since last increase: 002
# Loss: (Train) 0.01278 | (Valid): 0.01466 - (mean)JSD: (Train) 0.08159 | (Valid) 0.10226
#
# Epoch: 005 | Epochs since last increase: 003
# Loss: (Train) 0.01278 | (Valid): 0.01466 - (mean)JSD: (Train) 0.07691 | (Valid) 0.10308
#
# Epoch: 006 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01268 | (Valid): 0.01420 - (mean)JSD: (Train) 0.07506 | (Valid) 0.09701
#
# Epoch: 007 | Epochs since last increase: 001
# Loss: (Train) 0.01259 | (Valid): 0.01437 - (mean)JSD: (Train) 0.07660 | (Valid) 0.09830
#
# Epoch: 008 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01232 | (Valid): 0.01394 - (mean)JSD: (Train) 0.07309 | (Valid) 0.09537
#
# Epoch: 009 | Epochs since last increase: 001
# Loss: (Train) 0.01240 | (Valid): 0.01459 - (mean)JSD: (Train) 0.07444 | (Valid) 0.10153
#
# Epoch: 010 | Epochs since last increase: 002
# Loss: (Train) 0.01224 | (Valid): 0.01431 - (mean)JSD: (Train) 0.07775 | (Valid) 0.10132
#
# Epoch: 011 | Epochs since last increase: 003
# Loss: (Train) 0.01211 | (Valid): 0.01417 - (mean)JSD: (Train) 0.07289 | (Valid) 0.09696
#
# Epoch: 012 | Epochs since last increase: 004
# Loss: (Train) 0.01207 | (Valid): 0.01430 - (mean)JSD: (Train) 0.07205 | (Valid) 0.09686
#
# Epoch: 013 | Epochs since last increase: 005
# Loss: (Train) 0.01198 | (Valid): 0.01419 - (mean)JSD: (Train) 0.07327 | (Valid) 0.09839
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 50.65 (0.84 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [5] - JSDs 0.07308750708870454 0.09536700839453194
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01245 | (Valid): 0.01430 - (mean)JSD: (Train) 0.07501 | (Valid) 0.09935
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01217 | (Valid): 0.01415 - (mean)JSD: (Train) 0.07321 | (Valid) 0.09953
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01218 | (Valid): 0.01449 - (mean)JSD: (Train) 0.07451 | (Valid) 0.09743
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01206 | (Valid): 0.01425 - (mean)JSD: (Train) 0.07296 | (Valid) 0.09942
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01195 | (Valid): 0.01387 - (mean)JSD: (Train) 0.07330 | (Valid) 0.09662
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01194 | (Valid): 0.01366 - (mean)JSD: (Train) 0.07244 | (Valid) 0.09693
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.35 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [6] - JSDs 0.07308750708870454 0.09536700839453194
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01239 | (Valid): 0.01403 - (mean)JSD: (Train) 0.07266 | (Valid) 0.09722
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01227 | (Valid): 0.01476 - (mean)JSD: (Train) 0.07522 | (Valid) 0.09965
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01223 | (Valid): 0.01419 - (mean)JSD: (Train) 0.07230 | (Valid) 0.09700
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01202 | (Valid): 0.01429 - (mean)JSD: (Train) 0.07446 | (Valid) 0.10002
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01200 | (Valid): 0.01422 - (mean)JSD: (Train) 0.07041 | (Valid) 0.09790
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01183 | (Valid): 0.01421 - (mean)JSD: (Train) 0.07301 | (Valid) 0.09740
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.47 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [7] - JSDs 0.07308750708870454 0.09536700839453194
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01241 | (Valid): 0.01469 - (mean)JSD: (Train) 0.07351 | (Valid) 0.09806
#
# Epoch: 002 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01237 | (Valid): 0.01377 - (mean)JSD: (Train) 0.07143 | (Valid) 0.09400
#
# Epoch: 003 | Epochs since last increase: 001
# Loss: (Train) 0.01203 | (Valid): 0.01428 - (mean)JSD: (Train) 0.07626 | (Valid) 0.09967
#
# Epoch: 004 | Epochs since last increase: 002
# Loss: (Train) 0.01199 | (Valid): 0.01442 - (mean)JSD: (Train) 0.07439 | (Valid) 0.09955
#
# Epoch: 005 | Epochs since last increase: 003
# Loss: (Train) 0.01205 | (Valid): 0.01464 - (mean)JSD: (Train) 0.07397 | (Valid) 0.09960
#
# Epoch: 006 | Epochs since last increase: 004
# Loss: (Train) 0.01199 | (Valid): 0.01367 - (mean)JSD: (Train) 0.07347 | (Valid) 0.09630
#
# Epoch: 007 | Epochs since last increase: 005
# Loss: (Train) 0.01174 | (Valid): 0.01471 - (mean)JSD: (Train) 0.07312 | (Valid) 0.10060
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 27.34 (0.46 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [8] - JSDs 0.0714325881165576 0.09400198831075432
# Epoch: 001 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.01224 | (Valid): 0.01379 - (mean)JSD: (Train) 0.07018 | (Valid) 0.09066
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01197 | (Valid): 0.01361 - (mean)JSD: (Train) 0.07141 | (Valid) 0.09283
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01196 | (Valid): 0.01427 - (mean)JSD: (Train) 0.07174 | (Valid) 0.09870
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01190 | (Valid): 0.01353 - (mean)JSD: (Train) 0.07029 | (Valid) 0.09319
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01168 | (Valid): 0.01430 - (mean)JSD: (Train) 0.07380 | (Valid) 0.09827
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01171 | (Valid): 0.01435 - (mean)JSD: (Train) 0.07502 | (Valid) 0.09937
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.56 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [9] - JSDs 0.07017906077500177 0.09066029823458961
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01115 | (Valid): 0.01347 - (mean)JSD: (Train) 0.06793 | (Valid) 0.09538
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01107 | (Valid): 0.01353 - (mean)JSD: (Train) 0.06791 | (Valid) 0.09564
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01088 | (Valid): 0.01341 - (mean)JSD: (Train) 0.06699 | (Valid) 0.09475
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01095 | (Valid): 0.01339 - (mean)JSD: (Train) 0.06648 | (Valid) 0.09427
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01086 | (Valid): 0.01348 - (mean)JSD: (Train) 0.06750 | (Valid) 0.09572
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01084 | (Valid): 0.01342 - (mean)JSD: (Train) 0.06603 | (Valid) 0.09456
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.41 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [10] - JSDs 0.07017906077500177 0.09066029823458961
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01109 | (Valid): 0.01350 - (mean)JSD: (Train) 0.06737 | (Valid) 0.09445
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.01103 | (Valid): 0.01323 - (mean)JSD: (Train) 0.06725 | (Valid) 0.09249
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.01096 | (Valid): 0.01338 - (mean)JSD: (Train) 0.06674 | (Valid) 0.09390
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.01091 | (Valid): 0.01318 - (mean)JSD: (Train) 0.06563 | (Valid) 0.09202
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.01094 | (Valid): 0.01336 - (mean)JSD: (Train) 0.06618 | (Valid) 0.09408
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.01082 | (Valid): 0.01353 - (mean)JSD: (Train) 0.06556 | (Valid) 0.09416
#
# Finished training (checkpoint saved in: ModelCheckpoint_1.pt)
# Time elapsed: 23.44 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_1.pt
# Exp [1] - Restart [11] - JSDs 0.07017906077500177 0.09066029823458961
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.01115 | (Valid): 0.01348 - (mean)JSD: (Train) 0.06764 | (Valid) 0.09542
#
# ...
# Loss: (Train) 0.00950 | (Valid): 0.01177 - (mean)JSD: (Train) 0.05695 | (Valid) 0.08030
#
# Epoch: 008 | Epochs since last increase: 004
# Loss: (Train) 0.00950 | (Valid): 0.01172 - (mean)JSD: (Train) 0.05760 | (Valid) 0.08049
#
# Epoch: 009 | Epochs since last increase: 005
# Loss: (Train) 0.00941 | (Valid): 0.01168 - (mean)JSD: (Train) 0.05666 | (Valid) 0.08005
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 35.17 (0.59 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [10] - JSDs 0.05722160163835145 0.07904664783662754
# Epoch: 001 | Epochs since last increase: 000 | Better solution found
# Loss: (Train) 0.00958 | (Valid): 0.01158 - (mean)JSD: (Train) 0.05738 | (Valid) 0.07851
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00957 | (Valid): 0.01176 - (mean)JSD: (Train) 0.05688 | (Valid) 0.07963
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00952 | (Valid): 0.01170 - (mean)JSD: (Train) 0.05852 | (Valid) 0.08078
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00949 | (Valid): 0.01181 - (mean)JSD: (Train) 0.05792 | (Valid) 0.08162
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00946 | (Valid): 0.01178 - (mean)JSD: (Train) 0.05826 | (Valid) 0.08042
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00945 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05715 | (Valid) 0.08020
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.43 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [11] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00959 | (Valid): 0.01168 - (mean)JSD: (Train) 0.05739 | (Valid) 0.07984
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00949 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05693 | (Valid) 0.07952
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00949 | (Valid): 0.01175 - (mean)JSD: (Train) 0.05730 | (Valid) 0.08037
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00944 | (Valid): 0.01164 - (mean)JSD: (Train) 0.05720 | (Valid) 0.08023
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00939 | (Valid): 0.01174 - (mean)JSD: (Train) 0.05797 | (Valid) 0.08066
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00940 | (Valid): 0.01177 - (mean)JSD: (Train) 0.05646 | (Valid) 0.08001
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.39 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [12] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00956 | (Valid): 0.01178 - (mean)JSD: (Train) 0.05725 | (Valid) 0.08017
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00951 | (Valid): 0.01172 - (mean)JSD: (Train) 0.05680 | (Valid) 0.07941
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00946 | (Valid): 0.01178 - (mean)JSD: (Train) 0.05778 | (Valid) 0.08096
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00941 | (Valid): 0.01173 - (mean)JSD: (Train) 0.05772 | (Valid) 0.08147
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00943 | (Valid): 0.01173 - (mean)JSD: (Train) 0.05620 | (Valid) 0.07972
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00937 | (Valid): 0.01180 - (mean)JSD: (Train) 0.05715 | (Valid) 0.08086
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.55 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [13] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00957 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05736 | (Valid) 0.08023
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00950 | (Valid): 0.01181 - (mean)JSD: (Train) 0.05722 | (Valid) 0.08040
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00951 | (Valid): 0.01176 - (mean)JSD: (Train) 0.05711 | (Valid) 0.08073
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00946 | (Valid): 0.01166 - (mean)JSD: (Train) 0.05652 | (Valid) 0.07862
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00941 | (Valid): 0.01179 - (mean)JSD: (Train) 0.05634 | (Valid) 0.07985
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00942 | (Valid): 0.01166 - (mean)JSD: (Train) 0.05663 | (Valid) 0.07969
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.39 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [14] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00948 | (Valid): 0.01159 - (mean)JSD: (Train) 0.05660 | (Valid) 0.07864
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00942 | (Valid): 0.01156 - (mean)JSD: (Train) 0.05708 | (Valid) 0.07966
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00937 | (Valid): 0.01158 - (mean)JSD: (Train) 0.05678 | (Valid) 0.07958
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00935 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05673 | (Valid) 0.08029
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00934 | (Valid): 0.01167 - (mean)JSD: (Train) 0.05685 | (Valid) 0.08031
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00933 | (Valid): 0.01163 - (mean)JSD: (Train) 0.05707 | (Valid) 0.08050
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.60 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [15] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00940 | (Valid): 0.01175 - (mean)JSD: (Train) 0.05665 | (Valid) 0.08009
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00941 | (Valid): 0.01158 - (mean)JSD: (Train) 0.05693 | (Valid) 0.07901
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00940 | (Valid): 0.01161 - (mean)JSD: (Train) 0.05639 | (Valid) 0.07909
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00934 | (Valid): 0.01161 - (mean)JSD: (Train) 0.05708 | (Valid) 0.07954
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00932 | (Valid): 0.01158 - (mean)JSD: (Train) 0.05669 | (Valid) 0.07948
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00933 | (Valid): 0.01168 - (mean)JSD: (Train) 0.05641 | (Valid) 0.07980
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.30 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [16] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00941 | (Valid): 0.01172 - (mean)JSD: (Train) 0.05701 | (Valid) 0.08028
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00941 | (Valid): 0.01172 - (mean)JSD: (Train) 0.05625 | (Valid) 0.07934
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00940 | (Valid): 0.01158 - (mean)JSD: (Train) 0.05673 | (Valid) 0.07945
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00936 | (Valid): 0.01173 - (mean)JSD: (Train) 0.05585 | (Valid) 0.07949
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00935 | (Valid): 0.01168 - (mean)JSD: (Train) 0.05591 | (Valid) 0.07905
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00934 | (Valid): 0.01155 - (mean)JSD: (Train) 0.05626 | (Valid) 0.07869
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.47 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [17] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00943 | (Valid): 0.01162 - (mean)JSD: (Train) 0.05713 | (Valid) 0.07961
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00941 | (Valid): 0.01166 - (mean)JSD: (Train) 0.05691 | (Valid) 0.08005
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00936 | (Valid): 0.01164 - (mean)JSD: (Train) 0.05629 | (Valid) 0.07916
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00933 | (Valid): 0.01165 - (mean)JSD: (Train) 0.05664 | (Valid) 0.07971
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00934 | (Valid): 0.01163 - (mean)JSD: (Train) 0.05664 | (Valid) 0.07997
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00931 | (Valid): 0.01166 - (mean)JSD: (Train) 0.05655 | (Valid) 0.08021
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.40 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [18] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00939 | (Valid): 0.01171 - (mean)JSD: (Train) 0.05607 | (Valid) 0.07911
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00940 | (Valid): 0.01172 - (mean)JSD: (Train) 0.05723 | (Valid) 0.08047
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00935 | (Valid): 0.01162 - (mean)JSD: (Train) 0.05648 | (Valid) 0.07938
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00934 | (Valid): 0.01167 - (mean)JSD: (Train) 0.05682 | (Valid) 0.07982
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00937 | (Valid): 0.01164 - (mean)JSD: (Train) 0.05682 | (Valid) 0.08007
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00935 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05680 | (Valid) 0.08035
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.56 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [19] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00941 | (Valid): 0.01160 - (mean)JSD: (Train) 0.05710 | (Valid) 0.07957
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00939 | (Valid): 0.01163 - (mean)JSD: (Train) 0.05723 | (Valid) 0.08015
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00938 | (Valid): 0.01167 - (mean)JSD: (Train) 0.05656 | (Valid) 0.07951
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00940 | (Valid): 0.01165 - (mean)JSD: (Train) 0.05685 | (Valid) 0.07978
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00933 | (Valid): 0.01154 - (mean)JSD: (Train) 0.05639 | (Valid) 0.07869
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00934 | (Valid): 0.01163 - (mean)JSD: (Train) 0.05713 | (Valid) 0.08016
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.58 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [20] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00941 | (Valid): 0.01167 - (mean)JSD: (Train) 0.05693 | (Valid) 0.07986
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00940 | (Valid): 0.01156 - (mean)JSD: (Train) 0.05646 | (Valid) 0.07854
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00940 | (Valid): 0.01171 - (mean)JSD: (Train) 0.05661 | (Valid) 0.08015
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00937 | (Valid): 0.01155 - (mean)JSD: (Train) 0.05693 | (Valid) 0.07896
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00934 | (Valid): 0.01162 - (mean)JSD: (Train) 0.05655 | (Valid) 0.07993
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00935 | (Valid): 0.01170 - (mean)JSD: (Train) 0.05623 | (Valid) 0.07878
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.60 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [21] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00940 | (Valid): 0.01174 - (mean)JSD: (Train) 0.05658 | (Valid) 0.07906
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00938 | (Valid): 0.01168 - (mean)JSD: (Train) 0.05630 | (Valid) 0.07974
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00938 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05710 | (Valid) 0.08064
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00937 | (Valid): 0.01159 - (mean)JSD: (Train) 0.05690 | (Valid) 0.08008
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00933 | (Valid): 0.01168 - (mean)JSD: (Train) 0.05568 | (Valid) 0.07870
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00935 | (Valid): 0.01167 - (mean)JSD: (Train) 0.05621 | (Valid) 0.07996
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.44 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [22] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00941 | (Valid): 0.01161 - (mean)JSD: (Train) 0.05702 | (Valid) 0.07959
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00945 | (Valid): 0.01159 - (mean)JSD: (Train) 0.05696 | (Valid) 0.07918
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00939 | (Valid): 0.01173 - (mean)JSD: (Train) 0.05617 | (Valid) 0.07975
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00933 | (Valid): 0.01160 - (mean)JSD: (Train) 0.05690 | (Valid) 0.07958
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00936 | (Valid): 0.01164 - (mean)JSD: (Train) 0.05594 | (Valid) 0.07936
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00930 | (Valid): 0.01169 - (mean)JSD: (Train) 0.05629 | (Valid) 0.07963
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.50 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [23] - JSDs 0.05738215551375162 0.07851100795069492
# Epoch: 001 | Epochs since last increase: 000
# Loss: (Train) 0.00942 | (Valid): 0.01162 - (mean)JSD: (Train) 0.05644 | (Valid) 0.07895
#
# Epoch: 002 | Epochs since last increase: 001
# Loss: (Train) 0.00939 | (Valid): 0.01173 - (mean)JSD: (Train) 0.05801 | (Valid) 0.08104
#
# Epoch: 003 | Epochs since last increase: 002
# Loss: (Train) 0.00941 | (Valid): 0.01173 - (mean)JSD: (Train) 0.05714 | (Valid) 0.08028
#
# Epoch: 004 | Epochs since last increase: 003
# Loss: (Train) 0.00939 | (Valid): 0.01160 - (mean)JSD: (Train) 0.05673 | (Valid) 0.07934
#
# Epoch: 005 | Epochs since last increase: 004
# Loss: (Train) 0.00934 | (Valid): 0.01170 - (mean)JSD: (Train) 0.05609 | (Valid) 0.07982
#
# Epoch: 006 | Epochs since last increase: 005
# Loss: (Train) 0.00931 | (Valid): 0.01171 - (mean)JSD: (Train) 0.05648 | (Valid) 0.08004
#
# Finished training (checkpoint saved in: ModelCheckpoint_9.pt)
# Time elapsed: 23.32 (0.39 Minutes)
# Autoloading best parameters onto model (auto_load_model_on_finish==True)
# Restoring checkpoint: ModelCheckpoint_9.pt
# Exp [9] - Restart [24] - JSDs 0.05738215551375162 0.07851100795069492

# %% [markdown]
# In the end, we have a very satisfactory JSD of 7.974%!

# %%
jsd = 0
for exp in experiments:
    cur_jsd = AS.getMeanJSD(exp, "test")
    print("Test accuracy:", "{:2f}%".format(cur_jsd*100))
    jsd += cur_jsd

print(f"Mean JSD: {(jsd/10) * 100}%")
# Out:
# Test accuracy: 8.646763%
# Test accuracy: 8.270927%
# Test accuracy: 9.185757%
# Test accuracy: 10.056727%
# Test accuracy: 8.671460%
# Test accuracy: 7.788181%
# Test accuracy: 8.113168%
# Test accuracy: 8.163213%
# Test accuracy: 7.717306%
# Test accuracy: 9.374959%
# Mean JSD: 8.598846208617214%

# %%
from scipy.spatial import distance

jsds_ = []
for i, exp in enumerate(experiments): 
    loader      = exp.test_loader
    proportions = exp.Y_test_prop

    y_preds = AS.predict(exp, loader)
    for j in range(len(y_preds)):
        # i + 1 to get which fold the jsd belongs to
        jsds_.append([distance.jensenshannon(proportions[j], y_preds[j]), i+1])

# %%
df_for_plot = pd.DataFrame(jsds_, columns=['JSD', 'FOLD'])
df_for_plot.to_csv("df_for_plot.csv")

# %%
for i, exp in enumerate(experiments): 
    loader      = exp.test_loader
    proportions = exp.Y_test_prop

    jsds_ = []
    y_preds = AS.predict(exp, loader)
    for j in range(len(y_preds)):
        # i + 1 to get which fold the jsd belongs to
        jsds_.append(distance.jensenshannon(proportions[j], y_preds[j])) 
    print(f"SD: {np.std(jsds_)*100:0.3}%")
# Out:
# SD: 7.97%
# SD: 7.11%
# SD: 8.43%
# SD: 8.07%
# SD: 8.28%
# SD: 7.74%
# SD: 7.83%
# SD: 8.14%
# SD: 8.15%
# SD: 8.53%
